# %%
# push!(LOAD_PATH, raw"C:\Users\evanh\Box\Cornell\CACO\2022\Analysis\camera-calibration") # Point to Seth's repo location
# %matplotlib notebook
# import ExtrinsicCameraCalibration as ECC, RemoveImageDistortion as RID
import CSV, DataFrames
import PyPlot as plt
import Glob
import Statistics#, NaNStatistics
import Geodesy
import IRQIV
import Pkg
import Dates
import LaTeXStrings
import TiffImages
import FixedPointNumbers
import HDF5
plt.pygui(true) # sets plots to popup instead of inline
# Out:
# true

# %%
# Select & filter GPS data from IntertialSense EVB-2
plt.close()
GPSpath = raw"C:\Users\evanh\Box\Cornell\CACO\2022\CACO_GPS"
folders = readdir(GPSpath)
GCPxyz_us = Any[]
GCPlla_us = Any[]
GCPxyz_fix_ds = Any[]
fixpts = Any[]
gcp6a = Any[]
gcpo1a = Any[]
GCPnames = Any[]
j = 0
pltdim = 1 # dimension to plot
for (i,folder) in enumerate(folders)
    fullfile = GPSpath * "\\" * folder
    filename = readdir(Glob.glob"*POS.csv", fullfile)
    if occursin("US_FOV1", fullfile) == true || occursin("_DS_", fullfile) == true # Not using FOV1, focused on US only
        continue
    end
    GCP = CSV.read(filename, DataFrames.DataFrame)
    pos = GCP[:,[9, 10, 11, 16]] # lla 1-3 + status (code 0x00000C00 = RTK_FIX according to pg. 138: https://docs.inertialsense.com/user-manual/reference/user_manual_pdf/InertialSenseDocs.pdf)
    posfix = filter(row->any(occursin.("C", row.status[end-2:end-2])), pos) # from https://discourse.julialang.org/t/better-way-to-filter-strings-from-dataframe/88012
    if length(posfix.status) == 0 # No RTK_FIX (filtered out)
        posnf = pos
        if occursin("FOV2_GCPo2", fullfile) == true # Filtering jump
            deleteat!(posnf, 103:size(posnf,1))
            replace!(posnf[!,"lla[0]"] .= maximum(posnf[!,"lla[0]"]))
#             deleteat!(posnf, 1:140)
#             deleteat!(posnf, 1:1165)
#             dump(posnf[:,1])
#             show(posnf[:,"lla[0]"])
        end
        if occursin("FOV2_GCP1", fullfile) == true # Acceleration filter
            for k = 1:(size(posnf,1)-1)
                k = k+1
                if posnf[k-1,3] - posnf[k,3] > .5
                    posnf[k,:] = posnf[k-1,:]
                end
            end
#             deleteat!(posnf, 1660:2771)
            replace!(posnf[!,"lla[1]"] .= Statistics.median(posnf[!,"lla[1]"]))
        end
        if occursin("FOV2_GCP3", fullfile) == true # Filtering
            deleteat!(posnf, 2329:size(posnf,1))
            replace!(posnf[!,"lla[1]"] .= maximum(posnf[!,"lla[1]"]))
#             replace!(posnf[!,"lla[0]"] .= maximum(posnf[!,"lla[0]"]))
        end
        if occursin("FOV2_GCP5", fullfile) == true # Filtering
            continue
#             deleteat!(posnf, 2323:size(posnf,1))
#             deleteat!(posnf, 1:745)
#             deleteat!(posnf, 2324:size(posnf,1))
#             deleteat!(posnf, 1:2321)
#             replace!(posnf[!,"lla[0]"] .= Statistics.mean(posnf[!,"lla[0]"][250:350]))
            replace!(posnf[!,"lla[1]"] .= minimum(posnf[!,"lla[1]"]))
        end
#         dump(last(fullfile, 8))
        plt.plot(posnf[:,pltdim], label = last(fullfile, 8))
        pos = posnf
    else
        push!(fixpts, length(posfix.status), last(fullfile, 9))
        if occursin("DS_GCPb6", fullfile) == true # Filtering jump
#             deleteat!(posfix, 56:140)
        end
        if occursin("DS_GCPb3", fullfile) == true # Filtering jump - roughly half high and half low (average?)
            deleteat!(posfix, 227:249)
        end
        if occursin("DS_GCPo2", fullfile)
            continue
        end
        j = j+1
        pos = posfix
        plt.plot(posfix[:,pltdim], label = last(fullfile, 8))
    end
#     # visualize spread before taking mean, or look at SDs
    avgLLA = Statistics.mean.(eachcol(pos[:,1:3]))
#     plt.scatter(x = avgLLA[2], y = avgLLA[1], label = last(fullfile, 8))#, label = last(fullfile, 8))
#     if occursin("FOV2_GCP6", fullfile) == true
#         push!(gcp6a, avgLLA[3]) # save elevation for US GCP (on deck) to guess US camera elevation
#     end
#     if occursin("DS_GCP", fullfile) == true
#         push!(gcpo1a, avgLLA[3]) # save elevation for DS GCP (lowest bolt) to guess DS camera elevation
#     end
    GCP_LLA = Geodesy.LLA(avgLLA[1], avgLLA[2], avgLLA[3])
#     dump(filename)
#     dump(GCP_LLA)
    GCP_UTM = Geodesy.UTMZ(GCP_LLA, Geodesy.wgs84) # Inertialsense uses WGS84 - see manual link above
#     if occursin("US_FOV2", fullfile) == true
    push!(GCPxyz_us, GCP_UTM)
    push!(GCPlla_us, GCP_LLA)
#     elseif occursin("_DS_", fullfile) == true 
#         push!(GCPxyz_fix_ds, GCP_UTM)
#     else continue
#     end
    push!(GCPnames, last(fullfile, 9))
    dump(last(fullfile, 9))
    dump(GCP_LLA)
end
plt.legend()
# dump(GCPxyz_us)
# GCPnames
# fixpts
# DS GCPs b7 & b6 are over 1m apart in elevation on figure, actually only 2.5 in apart on fence??
# US GCP 4 over 2m higher than all others??
# Out:
# String "O
# 90.0%┣████████████████████████████████████████
# V2_GCPo1
# ▌    ┫ 90/100 [01:27<00:10, 1it/s]
# "
# Geodesy.LLA{Float64}
#   lat: Float64
# 91.0%┣█████████████████████████████████████████    ┫ 91/100 [01:42<00:10, 1s/it]
# 41.93122727292091
#   lon: Float64 -70.06422688241354
# 92.0%┣█████████████████████████████████████████▍   ┫ 92/100 [01:43<00:09, 1s/it]
#   alt
# : Float64 -26.65070085021623
# 93.0%┣█████████████████████████████████████████
# String "OV2_G
# ▉   ┫ 93/100 [01:44<00:08, 1s/it]
# CPo2"
# Geodesy.LLA{Float64}
# 94.0%┣██████████████████████████████████████████▎  ┫ 94/100 [01:55<00:07, 1s/it]
#   lat: Float64 41.93120445000001
#   lon:
# 95.0%┣██████████████████████████████████████████▊
# Float64 -70.06421506372548
# ┫ 95/100 [01:56<00:06, 1s/it]
#   alt: Float64 -26.367048429901963
# 96.0%┣███████████████████████████████████████████▏
# String "F
#  ┫ 96/100 [01:57<00:05, 1s/it]
# OV2_GCP2"
# Geodesy.LLA{
# 97.0%┣███████████████████████████████████████████▋ ┫ 97/100 [02:07<00:04, 1s/it]
# Float64}
#   lat: Float64 41.93121786187102
# 98.0%┣████████████████████████████████████████████ ┫ 98/100 [02:08<00:03, 1s/it]
#   lon: Float64 -70.06423069274999
#   alt: Float64
# 99.0%┣████████████████████████████████████████████▌┫ 99/100 [02:09<00:01, 1s/it]
# -25.47874955067313
# String "FOV2_GCP3
# 100.0%┣███████████████████████████████████████████┫ 100/100 [02:10<00:00, 1s/it]
# "
# Geodesy.LLA{Float64}
#   lat: Float64 41.931219593202464
#   lon: Float64 -70.06423087931903
#   alt: Float64 -24.460789065643237
# String "FOV2_GCP4"
# Geodesy.LLA{Float64}
#   lat: Float64 41.93122604976026
#   lon: Float64 -70.06423501317903
#   alt: Float64 -22.90844757928802
# String "FOV2_GCP1"
# Geodesy.LLA{Float64}
#   lat: Float64 41.9312088546059
#   lon: Float64 -70.06423071822974
#   alt: Float64 -25.37639133084033
# String "FOV2_GCP6"
# Geodesy.LLA{Float64}
#   lat: Float64 41.93121046950438
#   lon: Float64 -70.06424940660769
#   alt: Float64 -25.993972859973233
# No handles with labels found to put in legend.
# PyObject <matplotlib.legend.Legend object at 0x0000000068532FA0>

# %%
# Camera location approximation:
camll_us = [41.931168, -70.064190] # Guess from google maps
camll_ds = [41.931099, -70.064524] # ''
ft_to_m = 0.3048
camelev_us = sqrt(9^2-2^2)*ft_to_m # Have measurement of camera to deck (?) for US side
# camelev_ds = gcpo1a[1] + 6.5*ft_to_m # Guess DS camera offset from board GCP elev based on photos
cam_LLA_us = Geodesy.LLA(camll_us[1], camll_us[2], camelev_us)
cam_UTM_us = Geodesy.UTMZ(cam_LLA_us, Geodesy.wgs84)
# cam_LLA_ds = Geodesy.LLA(camll_ds[1], camll_ds[2], camelev_ds)
# cam_UTM_ds = Geodesy.UTMZ(cam_LLA_ds, Geodesy.wgs84)

# Camera angle approximation:
fl = 1214.2857142857144 # In pixels - from Seth
azimuth_us = deg2rad(5) # Guess from google maps
tilt_us = atan(70/62) # Approx. from photo
roll_us = atan(20/85) # ''
# azimuth_ds = 315 * (pi/180) # Guess from google maps
# tilt_ds = atan(120/34) # Approx. from photo
# roll_ds = atan(7/50) # ''

ECPs_us = ECC.ExtrinsicCalibrationParameters(azimuth_us, tilt_us, roll_us, fl, cam_UTM_us.x, cam_UTM_us.y, cam_UTM_us.z)
# ECPs_ds = ECC.ExtrinsicCalibrationParameters(azimuth_ds, tilt_ds, roll_ds, fl, cam_UTM_ds.x, cam_UTM_ds.y, cam_UTM_ds.z)
dump(ECPs_us)
# dump(ECPs_ds)
# Out:
# UndefVarError: ECC not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[275]:21

# %%
# Guesses of GCP elevation, with bridge deck as z=0:
# Posts are 35" high off bridge deck based on photos from ME, 0.0254 m/in
us_bo1_zg = [0] # Estimated on deck
us_bo2_zg = [0] # "
us_GCP1_zg = [(35-4)*0.0254] # Tape approx. 4" below top of fence
us_GCP2_zg = [(17.5+6)*0.0254] # Top of first rung is 17.5" from deck, + 6" to center of 12" GCP
us_GCP3_zg = [(17.5+6)*0.0254] # "
us_GCP4_zg = [(35-4)*0.0254] # Tape approx. 4" below top of fence
us_GCP5_zg = [0] # On deck
us_GCP6_zg = [2*0.0254] # On wood cover ~2" above deck
GCPzg_us = [us_bo1_zg, us_bo2_zg, us_GCP2_zg, us_GCP3_zg, us_GCP4_zg, us_GCP1_zg, #us_GCP5_zg, 
    us_GCP6_zg]
# Out:
# 7-element Vector{Vector{Float64}}:
#  [0.0]
#  [0.0]
#  [0.5969]
#  [0.5969]
#  [0.7874]
#  [0.7874]
#  [0.0508]

# %%
# View selected images of GCPs - hit enter in readline to advance figure
plt.close()
IMGpath = raw"C:\Users\evanh\Box\Cornell\CACO\2022\Analysis\GCP_photos"
folders = readdir(IMGpath)
for (i,folder) in enumerate(folders)
    fullfile = IMGpath * "\\" * folder
    image = plt.imread(fullfile)
#     dump(size(image))
    plt.imshow(image; extent = [1,1344,784,1])
    plt.title(last(fullfile, 9))
    readline()
end
# DS board o2 out of frame
# Out:
# InterruptException:
#
# Stacktrace:
#   [1] try_yieldto(undo::typeof(Base.ensure_rescheduled))
#     @ Base .\task.jl:710
#   [2] wait
#     @ .\task.jl:769 [inlined]
#   [3] wait(c::Base.GenericCondition{Base.Threads.SpinLock})
#     @ Base .\condition.jl:106
#   [4] wait(fdw::FileWatching._FDWatcher; readable::Bool, writable::Bool)
#     @ FileWatching C:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.6\FileWatching\src\FileWatching.jl:533
#   [5] wait
#     @ C:\Users\evanh\.julia\packages\ZMQ\lrABE\src\socket.jl:93 [inlined]
#   [6] _recv!(socket::ZMQ.Socket, zmsg::Base.RefValue{ZMQ._Message})
#     @ ZMQ C:\Users\evanh\.julia\packages\ZMQ\lrABE\src\comm.jl:80
#   [7] recv(socket::ZMQ.Socket, #unused#::Type{String})
#     @ ZMQ C:\Users\evanh\.julia\packages\ZMQ\lrABE\src\comm.jl:114
#   [8] recv_ipython(socket::ZMQ.Socket)
#     @ IJulia C:\Users\evanh\.julia\packages\IJulia\6TIq1\src\msg.jl:69
#   [9] readprompt(prompt::String; password::Bool)
#     @ IJulia C:\Users\evanh\.julia\packages\IJulia\6TIq1\src\stdio.jl:202
#  [10] readprompt
#     @ C:\Users\evanh\.julia\packages\IJulia\6TIq1\src\stdio.jl:195 [inlined]
#  [11] readline(io::IJulia.IJuliaStdio{Base.PipeEndpoint})
#     @ IJulia C:\Users\evanh\.julia\packages\IJulia\6TIq1\src\stdio.jl:237
#  [12] readline()
#     @ Base .\io.jl:507
#  [13] top-level scope
#     @ .\In[47]:11

# %%
# Finding GCPs in uv coordinates
# upper left is 0,0 viewing original .ats files in ResearchIR
us_bo1_uv = [475, 67]
us_bo2_uv = [1034, 570]
us_GCP1_uv = [279, 473]
us_GCP2_uv = [164, 248]
us_GCP3_uv = [45, 83]
us_GCP4_uv = [14, 15]
us_GCP5_uv = [235, 612]
us_GCP6_uv = [40, 741]
# Downstream - needs correction
# ds_board_o1_uv = [350.2, 40.4]
# ds_b1_uv = [725.0, 257.6]
# ds_b2_uv = [719.9, 268.9]
# ds_b3_uv = [694.3, 318.1]
# ds_b5_uv = [667.6, 356.3]
# ds_b6_uv = [731.3, 15.2]
# ds_b7_uv = [726.5, 43.4]
GCPuv_us = [us_bo1_uv, us_bo2_uv, us_GCP2_uv, us_GCP3_uv, us_GCP4_uv, us_GCP1_uv, #us_GCP5_uv, 
    us_GCP6_uv]
# GCPuv_fix_ds = [ds_board_o1_uv, ds_b7_uv, ds_b6_uv, ds_b3_uv]

# Finding uv coords of board tape
bo1_uv_us = [us_bo1_uv,
[456,101],
[437,136],
[415,172],
[395,208],
[373,245],
[352,283],
[330,321],
[306,360],
[285,400]]
bo2_uv_us = [us_bo2_uv,
[976,603],
[916,635],
[858,668],
[799,697],
[743,728],
[688,758],
[634,784]]
# Out:
# 8-element Vector{Vector{Int64}}:
#  [1034, 570]
#  [976, 603]
#  [916, 635]
#  [858, 668]
#  [799, 697]
#  [743, 728]
#  [688, 758]
#  [634, 784]

# %%
# Adding in board tape as additional GCPs 
plt.close()
tapeL = 0.5 * ft_to_m # tape distance is 6"
bo1_ant_us = [GCPxyz_us[1].x, GCPxyz_us[1].y]
bo1_ang_us = atan((504-275)/(433-38))+azimuth_us # atan(x/y) = degrees off of north + azimuth = estimate
bo1_tape_us = fill(0.0, 10, 2) # 10 pieces of tape on board, x&y
bo1_tape_us[1,:] = bo1_ant_us
for i = 1:9
    j = i+1
    bo1_tape_us[j,1] = bo1_ant_us[1] - (sin(bo1_ang_us)*tapeL*i) # multiply by index: # of 6" increments
    bo1_tape_us[j,2] = bo1_ant_us[2] - (cos(bo1_ang_us)*tapeL*i)
end
dump(bo1_tape_us)
bo2_ant_us = [GCPxyz_us[2].x, GCPxyz_us[2].y]
bo2_ang_us = atan((1107-667)/(781-535))+azimuth_us # atan(x/y) = degrees off of north + azimuth = estimate
bo2_tape_us = fill(0.0, 8, 2) # Only 8 pieces of tape visible
bo2_tape_us[1,:] = bo2_ant_us
for i = 1:7
    j = i+1
    bo2_tape_us[j,1] = bo2_ant_us[1] - (sin(bo2_ang_us)*tapeL*i) # multiply by index: # of 6" increments
    bo2_tape_us[j,2] = bo2_ant_us[2] - (cos(bo2_ang_us)*tapeL*i)
end
dump(bo2_tape_us)
plt.scatter(bo1_tape_us[:,1], bo1_tape_us[:,2])
plt.scatter(bo2_tape_us[:,1], bo2_tape_us[:,2])
bo1_tape_us[:,2]
sqrt((GCPxyz_us[2].x-GCPxyz_us[1].x)^2+(GCPxyz_us[2].y-GCPxyz_us[1].y)^2)
# Out:
# Array{Float64}((10, 2)) [411767.87045875855 4.642688116971011e6; 411767.78282169526 4.642687992289396e6; … ; 411767.1693622521 4.642687119518091e6; 411767.0817251888 4.642686994836476e6]
# Array{Float64}((8, 2)) [411768.81887039606 4.642685570787637e6; 411768.6798732784 4.642685508293146e6; … ; 411767.98488769017 4.642685195820697e6; 411767.8458905725 4.642685133326206e6]
# 2.717081966340984

# %%
thermpath = raw"C:\Users\evanh\Box\Cornell\CACO\2022\Thermistor\P6_CACO_July_2022.txt"
therm = CSV.read(thermpath, delim = ',', skipto = 48, DataFrames.DataFrame)
thermP = therm[:,2]
plt.plot(thermP)
# 360 lines per hour, 8640 lines per day
us_therm_z = (sqrt(9^2-2^2) + 1/3 + 7) * ft_to_m
ds_therm_z = 209/12*ft_to_m
# therm[9230,:] - thermistor started @ 6:30 on 7/13, moved downstream @ 8:12 am on 7/14
thermZ = us_therm_z.-thermP[1:9230]
thermZ = append!(thermZ, ds_therm_z.-thermP[9231:end])

plt.close("all")
thermT = string.(therm[:,4])
plt.plot(thermT[6302:6302+8638], thermP[6302:6302+8638])
plt.xticks(1:1200:length(thermZ[6302:6302+8638])#, rotation = 45
)
plt.xlabel("Time - July 14, 2022")
plt.ylabel("Thermistor pressure head (m)")
plt.rc("font",size=24)

# thermZf = open("therm_z_us.txt","w")
# show(thermZf, thermP[871:9230]) 
# close(thermZf)
# thermZread = open("therm_us_readme.txt", "w")
# write(thermZread, "Vertical distance of water surface to camera (m) from 8:55:00 on 7/13/22 to 8:08:10 on 7/14/22; \n")
# write(thermZread, "Adjusted by vertical offset from camera to thermistor (4.91m) with thermistor head subtracted; \n")
# write(thermZread, "Adjusted by vertical offset from camera to thermistor (4.91m) with thermistor head subtracted; \n")
# write(thermZread, "Indices corresponding to provided .ATS files: \n")
# write(thermZread, "003349: [6621:6660] \n")
# write(thermZread, "003359: [6988:7008] \n")
# write(thermZread, "003368: [7354:7374] \n")
# write(thermZread, "003377: [7708:7728] \n")
# write(thermZread, "003386: [8068:8088] \n")
# close(thermZread)
# Out:
# ┌ Warning: thread = 1 warning: parsed expected 1 columns, but didn't reach end of line around data row: 1. Parsing extra columns and widening final columnset
# └ @ CSV C:\Users\evanh\.julia\packages\CSV\b8ebJ\src\file.jl:577

# %%
therm[6302+8638,:]
# Out:
# DataFrameRow
#    Row │ * Sea-Bird SBE39 Data File:  Column2  Column3       Column4
#        │ Float64                      Float64  String15      Time
# ───────┼──────────────────────────────────────────────────────────────
#  14940 │                     25.8138    2.971   14 Jul 2022  23:59:50

# %%
# plt.plot(thermZ[871:9230])
plt.plot(thermP[871:9230])
therm[8068+871:8088+871,:]
# plt.plot(thermP[6621+871:8088+871])
# Out:
# 21×4 DataFrame
#  Row │ * Sea-Bird SBE39 Data File:  Column2  Column3       Column4
#      │ Float64                      Float64  String15      Time
# ─────┼──────────────────────────────────────────────────────────────
#    1 │                     23.4268    0.692   14 Jul 2022  07:19:40
#    2 │                     23.4221    0.692   14 Jul 2022  07:19:50
#    3 │                     23.4176    0.695   14 Jul 2022  07:20:00
#    4 │                     23.4148    0.694   14 Jul 2022  07:20:10
#    5 │                     23.4173    0.691   14 Jul 2022  07:20:20
#    6 │                     23.4163    0.692   14 Jul 2022  07:20:30
#    7 │                     23.4224    0.691   14 Jul 2022  07:20:40
#    8 │                     23.418     0.687   14 Jul 2022  07:20:50
#    9 │                     23.4155    0.691   14 Jul 2022  07:21:00
#   10 │                     23.4367    0.689   14 Jul 2022  07:21:10
#   11 │                     23.4221    0.692   14 Jul 2022  07:21:20
#   12 │                     23.4364    0.682   14 Jul 2022  07:21:30
#   13 │                     23.4283    0.685   14 Jul 2022  07:21:40
#   14 │                     23.4177    0.685   14 Jul 2022  07:21:50
#   15 │                     23.4189    0.687   14 Jul 2022  07:22:00
#   16 │                     23.4236    0.685   14 Jul 2022  07:22:10
#   17 │                     23.4164    0.687   14 Jul 2022  07:22:20
#   18 │                     23.419     0.685   14 Jul 2022  07:22:30
#   19 │                     23.416     0.684   14 Jul 2022  07:22:40
#   20 │                     23.4214    0.682   14 Jul 2022  07:22:50
#   21 │                     23.4251    0.681   14 Jul 2022  07:23:00

# %%
# therm[871,:] # 8:55 7/13 - therm in water US
# therm[9230,:] # 8:08:10 7/14 - last in-water reading US
# using Pkg
# Pkg.activate(expanduser("~/.julia/dev/IRQIV/"))
# include("CameraCalibrationHelpers.jl")
# Pkg.activate(raw"C:\Users\evanh\.julia\dev\IRQIV.jl\examples\CameraCalibrationHelpers.jl") # path to IRQIV directory
# TrueGCPxyz = [GCPxyz_us.x GCPxyz_us[all].y GCPzg_us[all]]
GCPxyz_us[:].x
# Out:
# type Array has no field x
#
# Stacktrace:
#  [1] getproperty(x::Vector{Any}, f::Symbol)
#    @ Base .\Base.jl:33
#  [2] top-level scope
#    @ In[35]:8

# %%
###############################################################################
# 
# CameraCalibrationHelpers.jl in /home/seth/.julia/dev/IRQIV/src/
# 
# Created: 2023-04-27 10:24:33 by seth@SASthinkpad
# last changed Time-stamp: <2023-04-27 13:34:02 seth>
# 
###############################################################################

###############################################################################
# run this file to load packages and define the functions that we'll use:
# include("CameraCalibrationHelpers.jl") # Moved this into local dir.
Pkg.activate(raw"C:\Users\evanh\.julia\dev\IRQIV.jl\examples\CameraCalibrationHelpers.jl") # path to IRQIV directory
###############################################################################


###############################################################################
# Run example using Sutter Slough calibration:
###############################################################################

# Define camera and its intrinsic parameters:
Camera = FLIR_SC8303_17mm
ι = IntrinsicCalibrationParameters(Camera)

# UTM coordinates of GCPs:
TrueGCPxyz = [GCPxyz_us[:,1] GCPxyz_us[:,2] GCPzg_us]

# Pixel coordinates of GCPs, before accounting for radial distortion:
DistortedImageGCPuv  = [ 1295.0  113.4
                         1244.3  725.3
                         1265.6  757.45
                         1335.0  138.3
                         115.7  471.5
                         137.6  272.5
                         173.6   57.1
                         82.4  761.0]

## Remove radial distortion from GCP target coordinates:
# 
# (the hcat other things on this line are just to convert the output from a
# Tuple to an Array)
TrueGCPuv = hcat(RemoveRadialDistortion(DistortedImageGCPuv[:,1], DistortedImageGCPuv[:,2], Camera)...)

# Camera position initial guess:
Camera_x = 624165.196
Camera_y = 4243306.056
Camera_z = 24.24 - 0.4          # antenna was placed above camera, 0.4m offset
#
# estimated camera orientation angles:
φ =  50                         # azimuth
τ = 215                         # tilt
σ =  90                         # roll
#
f = -1200 # nominal_focal_length_px (nominal lens focal length / pixel pitch)

# Initial guess of camera's extrinsic parameters:
χ = ExtrinsicCalibrationParameters(
    deg2rad(φ),
    deg2rad(τ),
    deg2rad(σ),
    f,
    Camera_x,  # x_c
    Camera_y,  # y_c
    Camera_z) # z_c


##############################################################################
plt.close("all")
GraphicallyExploreInitialCalibrationGuess(TrueGCPuv, TrueGCPxyz, χ, ι)# ,
                                          # frame=fill(NaN, ι.v₀*2 - 1 |> Int, ι.u₀*2 - 1 |> Int))
##############################################################################

##############################################################################
# Optionally, load an IR image and plot it in the background:
FLIR_filename = joinpath(raw"D:\CNRD_IR",
                         "Rec-DeFreesLab_-003349.ats")
IRimages = LoadATSImageSequence(FLIR_filename, 1, 2017)
# 
plt.close("all")
GraphicallyExploreInitialCalibrationGuess(TrueGCPuv, TrueGCPxyz, χ, ι, IRimages[1])# ,
##############################################################################
# Out:
#   Activating new environment at `C:\Users\evanh\.julia\dev\IRQIV.jl\examples\CameraCalibrationHelpers.jl\Project.toml`
# [ Info: (624198.903, 624191.7649649581)
# [ Info: (624221.304, 624203.1003668802)
# [ Info: (624223.368, 624203.6389393692)
# [ Info: (624200.707, 624192.4015051478)
# [ Info: (624171.856, 624168.8956599968)
# [ Info: (624169.447, 624167.0981831495)
# [ Info: (624167.042, 624165.1666486443)
# [ Info: (624175.137, 624171.5181389938)
# [ Info: (1303.315387044818, 1499.1425577647958)
# C:\Users\evanh\anaconda3\lib\site-packages\matplotlib\image.py:443: UserWarning: Warning: converting a masked element to nan.
#   dv = np.float64(self.norm.vmax) - np.float64(self.norm.vmin)
# C:\Users\evanh\anaconda3\lib\site-packages\matplotlib\image.py:444: UserWarning: Warning: converting a masked element to nan.
#   vmid = np.float64(self.norm.vmin) + dv / 2
# [ Info: (1250.1713727256965, 1524.8604917836303)
# C:\Users\evanh\anaconda3\lib\site-packages\matplotlib\image.py:443: UserWarning: Warning: converting a masked element to nan.
#   dv = np.float64(self.norm.vmax) - np.float64(self.norm.vmin)
# C:\Users\evanh\anaconda3\lib\site-packages\matplotlib\image.py:444: UserWarning: Warning: converting a masked element to nan.
#   vmid = np.float64(self.norm.vmin) + dv / 2
# [ Info: (1274.865166910621, 1559.7197874384015)
# [ Info: (1346.8148838272634, 1555.5924887039919)
# [ Info: (116.63409264267179, 299.0113686652757)
# [ Info: (139.22360912811874, 277.58757394470945)
# [ Info: (172.3746028238008, 285.9539433905176)
# [ Info: (73.24723146633139, 291.045892510343)
# ┌ Warning: Too few BHPHeaders to calculate fps!
# └ @ IRQIV.FLIRATSFiles C:\Users\evanh\.julia\dev\IRQIV\src\FLIRATSFiles.jl:412
# C:\Users\evanh\anaconda3\lib\site-packages\matplotlib\image.py:443: UserWarning: Warning: converting a masked element to nan.
#   dv = np.float64(self.norm.vmax) - np.float64(self.norm.vmin)
# C:\Users\evanh\anaconda3\lib\site-packages\matplotlib\image.py:444: UserWarning: Warning: converting a masked element to nan.
#   vmid = np.float64(self.norm.vmin) + dv / 2
# [ Info: (624198.903, 624191.7649649581)
# [ Info: (624221.304, 624203.1003668802)
# [ Info: (624223.368, 624203.6389393692)
# [ Info: (624200.707, 624192.4015051478)
# [ Info: (624171.856, 624168.8956599968)
# [ Info: (624169.447, 624167.0981831495)
# [ Info: (624167.042, 624165.1666486443)
# [ Info: (624175.137, 624171.5181389938)
# [ Info: (1303.315387044818, 1499.1425577647958)
# [ Info: (1250.1713727256965, 1524.8604917836303)
# [ Info: (1274.865166910621, 1559.7197874384015)
# [ Info: (1346.8148838272634, 1555.5924887039919)
# [ Info: (116.63409264267179, 299.0113686652757)
# [ Info: (139.22360912811874, 277.58757394470945)
# [ Info: (172.3746028238008, 285.9539433905176)
# [ Info: (73.24723146633139, 291.045892510343)
# PyObject Text(0.5, 0.98, 'red is calculated, black is provided\n\nExtrinsicCalibrationParameters\n  φ: Float64 0.872665\n  τ: Float64 3.75246\n  σ: Float64 1.5708\n  f: Float64 -1200.0\n  x_c: Float64 6.24165e5\n  y_c: Float64 4.24331e6\n  z_c: Float64 23.84\n')

# %%
###############################################################################
# 
# IRQIV_MWE.jl in /home/seth/.julia/dev/IRQIV/test/
# 
# Created: 2023-04-24 16:55:53 by seth@SASthinkpad
# last changed Time-stamp: <2023-04-26 15:08:17 seth>
# 
###############################################################################

###############################################################################
Pkg.activate(expanduser("~/.julia/dev/IRQIV/")) # path to IRQIV directory
using IRQIV
###############################################################################


###############################################################################
# 
### Select a dataset to operate on:
#
# Sutter Slough:
FLIR_filename = joinpath(raw"D:\CNRD_IR",
                         "Rec-DeFreesLab_-003318.ats") # 3349
ats_year = 2022
@assert isfile(FLIR_filename)
###############################################################################

###############################################################################
const M=64 # subwindow dims - horiz, N = vert.
const N=64
const rhoI = 20 # how far away to search (+/-) - i=horiz, j= vert
const rhoJ = 20 # Set these to visual estimates - plot one pair
MQD_parameters = (M=M, N=N, rhoI=rhoI, rhoJ=rhoJ)
###############################################################################


###############################################################################
DtFrames = 1                    # Δt, frames (ATS 3116 is at 10Hz)
data_output_rate_frames = 150    # difference between I1 sequence, frames - time sep of output
nImagePairs = 20 # can set to inf - all frames in file
# Can test on 10 pairs & look at histogram of displacements
###############################################################################


###############################################################################
# Load IR images:
I1inds = range(1, step=data_output_rate_frames, length=nImagePairs)
I2inds = I1inds .+ DtFrames
I1images = LoadATSImageSequence(FLIR_filename, I1inds, ats_year)
I2images = LoadATSImageSequence(FLIR_filename, I2inds, ats_year)
###############################################################################
# Remove image pairs when at least one image took place during NUC (calibration)
# mode:
if any(isnuc(I1images.Headers)) || any(isnuc(I2images.Headers))
    nuc_frames = isnuc(I1images.Headers) .| isnuc(I2images.Headers)
    I1inds = I1inds[.!( isnuc(I1images.Headers) .| isnuc(I2images.Headers) )]
    I2inds = I2inds[.!( isnuc(I1images.Headers) .| isnuc(I2images.Headers) )]
    I1images = LoadATSImageSequence(FLIR_filename, I1inds, ats_year)
    I2images = LoadATSImageSequence(FLIR_filename, I2inds, ats_year)
end
###############################################################################

###############################################################################
subwincorners = CartesianIndices(( (N+rhoI):N:(size(I1images,1)-(N+rhoI+1)),
                                   (M+rhoJ):M:(size(I1images,2)-(M+rhoJ+1)) ))
# ranges determine N/M-overlap,  want to workshop sub-regions here
###############################################################################


###############################################################################
# Initialize MQD calculation:
MQD_variables = initialize_MQD(I1images,
                               I2images,
                               subwincorners,
                               N, M,
                               rhoI, rhoJ)                              
###############################################################################

###############################################################################
# Perform the MQD analysis:
subpix_shifts_i, subpix_shifts_j, performance_message = perform_MQD(
    I1images, I2images, subwincorners, MQD_variables, MQD_parameters);
###############################################################################
jmean = Statistics.mean(subpix_shifts_j[:,:,:], dims=3)
imean = Statistics.mean(subpix_shifts_i[:,:,:], dims=3)
jmean = dropdims(jmean, dims=3)
imean = dropdims(imean, dims=3)
meanmags = Statistics.mean(hypot.(jmean, imean))

i = [ x[1] for x in Tuple.(subwincorners)]
j = [ x[2] for x in Tuple.(subwincorners)]
plt.close("all")
fig,axs = plt.subplots()
im = axs.imshow(I1images[:,:,1], alpha=0.3, vmin=8700, vmax=11800)
q = axs.quiver(j,i, jmean, imean, angles="xy")
# ax.invert_yaxis()
# Out:
#   Activating new environment at `C:\Users\evanh\Box\Cornell\CACO\2022\Analysis\IRQIV.jl\CACO_2022_jl\~\.julia\dev\IRQIV\Project.toml`
# 9.1%┣████                                       ┫ 1/11 [00:00<Inf:Inf, InfGs/it]
# 18.2%┣████████▌                                      ┫ 2/11 [00:00<00:02, 4it/s]
# 27.3%┣████████████▉                                  ┫ 3/11 [00:01<00:03, 3it/s]
# 36.4%┣█████████████████                              ┫ 4/11 [00:01<00:02, 3it/s]
# 45.5%┣█████████████████████▍                         ┫ 5/11 [00:01<00:02, 4it/s]
# 54.5%┣█████████████████████████▋                     ┫ 6/11 [00:01<00:01, 4it/s]
# 63.6%┣██████████████████████████████                 ┫ 7/11 [00:02<00:01, 4it/s]
# 72.7%┣██████████████████████████████████▏            ┫ 8/11 [00:02<00:01, 4it/s]
# 81.8%┣██████████████████████████████████████▌        ┫ 9/11 [00:02<00:01, 4it/s]
# 90.9%┣█████████████████████████████████████████▉    ┫ 10/11 [00:02<00:00, 4it/s]
# 100.0%┣█████████████████████████████████████████████┫ 11/11 [00:03<00:00, 4it/s]
# ┌ Info: Performance stats (MQD loop only)
# │ time [s]                       2.8870277
# │ subwins/s              65.81163041837111
# │ allocations [GB]                    0.72
# │ allocations [MB/subwin]                3.81
# │ time [m]                            0.05
# │ total n subwindows                  2090
# │ n image pairs                         11
# │ n subwindows in FOV                  190
# │ size(subwindows)                (10, 19)
# │ M, N                            (64, 64)
# │ rhoI, rhoJ                      (20, 20)
# │ allocations [B]                723470448
# │ allocations [MB]                  723.47
# │ gc time [s]                    0.2234536
# │ gc stats            Base.GC_Diff(723470448, 6314, 0, 76782, 4180, 0, 223453600, 16, 1)
# │ number of threads                      1
# │ Running on skylake CPU specs:
# │ Intel(R) Core(TM) i7-8550U CPU @ 1.80GHz:
# │        speed         user         nice          sys         idle          irq
# │ #1  1992 MHz    3164906            0      3644671     80028234       781437  ticks
# │ #2  1992 MHz    2908484            0      1231093     82698093        50125  ticks
# │ #3  1992 MHz    4834109            0      2312890     79690671        37593  ticks
# │ #4  1992 MHz    2324156            0      1550812     82962703        26109  ticks
# │ #5  1992 MHz    4245406            0      2136203     80456062        39296  ticks
# │ #6  1992 MHz    1955296            0      1419468     83462906        24031  ticks
# │ #7  1992 MHz    3125125            0      1731656     81980875        35421  ticks
# └ #8  1992 MHz    2622843            0      1732375     82482437        25890  ticks
# PyObject <matplotlib.quiver.Quiver object at 0x000000006CE5C5E0>

# %%
# Upstream IRQIV averaging
Pkg.activate(expanduser("~/.julia/dev/IRQIV/")) # path to IRQIV directory
using IRQIV


###############################################################################

###############################################################################
const M=64 # subwindow dims - horiz, N = vert.
const N=64
const rhoI = 40 # how far away to search (+/-) - i=horiz, j= vert
const rhoJ = 40 # Set these to visual estimates - plot one pair
MQD_parameters = (M=M, N=N, rhoI=rhoI, rhoJ=rhoJ)
###############################################################################


###############################################################################
DtFrames = 1                    # Δt, frames (ATS 3116 is at 10Hz)
data_output_rate_frames = 150    # difference between I1 sequence, frames - time sep of output
nImagePairs = 20 # can set to inf - all frames in file
# Can test on 10 pairs & look at histogram of displacements
###############################################################################


###############################################################################
# Load IR images:
I1inds = range(1, step=data_output_rate_frames, length=nImagePairs)
I2inds = I1inds .+ DtFrames

Nfiles = 37

meanmagsus = fill(NaN, Nfiles)
for f = 1:Nfiles
    file = f+3348
    FLIR_filename = joinpath(raw"D:\CNRD_IR",
                         "Rec-DeFreesLab_-00" * string.(file) * ".ats")
    ats_year = 2022
    @assert isfile(FLIR_filename)
    I1images = LoadATSImageSequence(FLIR_filename, I1inds, ats_year)
    I2images = LoadATSImageSequence(FLIR_filename, I2inds, ats_year)

    if any(isnuc(I1images.Headers)) || any(isnuc(I2images.Headers))
        nuc_frames = isnuc(I1images.Headers) .| isnuc(I2images.Headers)
        I1inds = I1inds[.!( isnuc(I1images.Headers) .| isnuc(I2images.Headers) )]
        I2inds = I2inds[.!( isnuc(I1images.Headers) .| isnuc(I2images.Headers) )]
        I1images = LoadATSImageSequence(FLIR_filename, I1inds, ats_year)
        I2images = LoadATSImageSequence(FLIR_filename, I2inds, ats_year)
    end

    subwincorners = CartesianIndices(( (N+rhoI):N:(size(I1images,1)-(N+rhoI+1)),
                                   (M+rhoJ):M:(size(I1images,2)-(M+rhoJ+1)) ))

    MQD_variables = initialize_MQD(I1images,
                                   I2images,
                                   subwincorners,
                                   N, M,
                                   rhoI, rhoJ)                              

    subpix_shifts_i, subpix_shifts_j, performance_message = perform_MQD(
        I1images, I2images, subwincorners, MQD_variables, MQD_parameters);
    ###############################################################################
    jmean = Statistics.mean(subpix_shifts_j[:,:,:], dims=3)
    imean = Statistics.mean(subpix_shifts_i[:,:,:], dims=3)
    jmean = dropdims(jmean, dims=3)
    imean = dropdims(imean, dims=3)
    meanmagsus[f] = Statistics.mean(hypot.(jmean, imean))

    i = [ x[1] for x in Tuple.(subwincorners)]
    j = [ x[2] for x in Tuple.(subwincorners)]
    
    plt.close("all")
    fig,ax = plt.subplots()
    im = ax.imshow(I1images[:,:,1], alpha=0.3, vmin=8700, vmax=11800)
    q = ax.quiver(j,i, jmean, imean, angles="xy")
    # ax.invert_yaxis()
    
    # Look at histogram of displacements
    fig, ax = plt.subplots()
    h1 = ax.hist(vec(subpix_shifts_i), 100, label="i", alpha=0.4);
    h2 = ax.hist(vec(subpix_shifts_j), 100, label="j", alpha=0.4);
    plt.legend()
    plt.show()
end
# Out:
#   Activating new environment at `C:\Users\evanh\Box\Cornell\CACO\2022\Analysis\IRQIV.jl\CACO_2022_jl\~\.julia\dev\IRQIV\Project.toml`
# 5.0%┣██▏                                        ┫ 1/20 [00:19<Inf:Inf, InfGs/it]
# 10.0%┣████▋                                         ┫ 2/20 [00:20<05:58, 20s/it]
# 15.0%┣███████                                       ┫ 3/20 [00:20<02:52, 10s/it]
# 20.0%┣█████████▍                                     ┫ 4/20 [00:21<01:50, 7s/it]
# 25.0%┣███████████▊                                   ┫ 5/20 [00:21<01:18, 5s/it]
# 30.0%┣██████████████                                 ┫ 6/20 [00:21<00:59, 4s/it]
# 35.0%┣████████████████▌                              ┫ 7/20 [00:21<00:46, 4s/it]
# 40.0%┣██████████████████▉                            ┫ 8/20 [00:22<00:37, 3s/it]
# 45.0%┣█████████████████████▏                         ┫ 9/20 [00:22<00:30, 3s/it]
# 50.0%┣███████████████████████                       ┫ 10/20 [00:22<00:25, 2s/it]
# 55.0%┣█████████████████████████▎                    ┫ 11/20 [00:23<00:21, 2s/it]
# 60.0%┣███████████████████████████▋                  ┫ 12/20 [00:23<00:17, 2s/it]
# 65.0%┣██████████████████████████████                ┫ 13/20 [00:23<00:14, 2s/it]
# 70.0%┣████████████████████████████████▏             ┫ 14/20 [00:24<00:11, 2s/it]
# 75.0%┣██████████████████████████████████▌           ┫ 15/20 [00:24<00:09, 2s/it]
# 80.0%┣████████████████████████████████████▉         ┫ 16/20 [00:24<00:06, 2s/it]
# 85.0%┣███████████████████████████████████████       ┫ 17/20 [00:25<00:05, 2s/it]
# 90.0%┣█████████████████████████████████████████▍    ┫ 18/20 [00:25<00:03, 1s/it]
# 95.0%┣███████████████████████████████████████████▊  ┫ 19/20 [00:25<00:01, 1s/it]
# 100.0%┣█████████████████████████████████████████████┫ 20/20 [00:26<00:00, 1s/it]
# ┌ Info: Performance stats (MQD loop only)
# │ time [s]                      25.9132065
# │ subwins/s               6.25163852261973
# │ allocations [GB]                    3.97
# │ allocations [MB/subwin]               24.48
# │ time [m]                            0.43
# │ total n subwindows                  3240
# │ n image pairs                         20
# │ n subwindows in FOV                  162
# │ size(subwindows)                 (9, 18)
# │ M, N                            (64, 64)
# │ rhoI, rhoJ                      (40, 40)
# │ allocations [B]               3965085723
# │ allocations [MB]                 3965.09
# │ gc time [s]                    0.8544337
# │ gc stats            Base.GC_Diff(3965085723, 16320, 0, 38223326, 8281, 0, 854433700, 33, 2)
# │ number of threads                      1
# │ Running on skylake CPU specs:
# │ Intel(R) Core(TM) i7-8550U CPU @ 1.80GHz:
# │        speed         user         nice          sys         idle          irq
# │ #1  1992 MHz     528562            0       568734     12612562        83062  ticks
# │ #2  1992 MHz     301875            0       292812     13115031         7984  ticks
# │ #3  1992 MHz     840500            0       472484     12396750        11546  ticks
# │ #4  1992 MHz     371671            0       283156     13054890         5750  ticks
# │ #5  1992 MHz     622468            0       421562     12665703         9687  ticks
# │ #6  1992 MHz     321812            0       199375     13188531         5562  ticks
# │ #7  1992 MHz     474843            0       342093     12892781        11593  ticks
# └ #8  1992 MHz     463062            0       279890     12966750         4656  ticks
# ┌ Warning: Too few BHPHeaders to calculate fps!
# └ @ IRQIV.FLIRATSFiles \Users\evanh\Box\Cornell\CACO\2022\Analysis\IRQIV.jl\src\FLIRATSFiles.jl:412
# ┌ Warning: Too few BHPHeaders to calculate fps!
# └ @ IRQIV.FLIRATSFiles \Users\evanh\Box\Cornell\CACO\2022\Analysis\IRQIV.jl\src\FLIRATSFiles.jl:412
# 50.0%┣█████████████████████▌                     ┫ 1/2 [00:00<Inf:Inf, InfGs/it]
# 100.0%┣███████████████████████████████████████████████┫ 2/2 [00:00<00:00, 3it/s]
# ┌ Info: Performance stats (MQD loop only)
# │ time [s]                       0.6352371
# │ subwins/s             255.02288830422532
# │ allocations [GB]                    0.19
# │ allocations [MB/subwin]                 1.2
# │ time [m]                            0.01
# │ total n subwindows                   324
# │ n image pairs                          2
# │ n subwindows in FOV                  162
# │ size(subwindows)                 (9, 18)
# │ M, N                            (64, 64)
# │ rhoI, rhoJ                      (40, 40)
# │ allocations [B]                194882560
# │ allocations [MB]                  194.88
# │ gc time [s]                    0.0137537
# │ gc stats            Base.GC_Diff(194882560, 1628, 0, 12793, 0, 0, 13753700, 1, 0)
# │ number of threads                      1
# │ Running on skylake CPU specs:
# │ Intel(R) Core(TM) i7-8550U CPU @ 1.80GHz:
# │        speed         user         nice          sys         idle          irq
# │ #1  1992 MHz     528828            0       568890     12616906        83093  ticks
# │ #2  1992 MHz     301953            0       292984     13119546         7984  ticks
# │ #3  1992 MHz     841750            0       472828     12399906        11546  ticks
# │ #4  1992 MHz     371843            0       283171     13059453         5750  ticks
# │ #5  1992 MHz     622734            0       421718     12670015         9703  ticks
# │ #6  1992 MHz     321921            0       199484     13193062         5562  ticks
# │ #7  1992 MHz     475015            0       342171     12897265        11593  ticks
# └ #8  1992 MHz     464218            0       280125     12970125         4671  ticks
# ┌ Warning: Too few BHPHeaders to calculate fps!
# └ @ IRQIV.FLIRATSFiles \Users\evanh\Box\Cornell\CACO\2022\Analysis\IRQIV.jl\src\FLIRATSFiles.jl:412
# ┌ Warning: Too few BHPHeaders to calculate fps!
# └ @ IRQIV.FLIRATSFiles \Users\evanh\Box\Cornell\CACO\2022\Analysis\IRQIV.jl\src\FLIRATSFiles.jl:412
# 50.0%┣█████████████████████▌                     ┫ 1/2 [00:00<Inf:Inf, InfGs/it]
# 100.0%┣███████████████████████████████████████████████┫ 2/2 [00:00<00:00, 3it/s]
# ┌ Info: Performance stats (MQD loop only)
# │ time [s]                       1.0985748
# │ subwins/s              147.4637867171175
# │ allocations [GB]                    0.19
# │ allocations [MB/subwin]                 1.2
# │ time [m]                            0.02
# │ total n subwindows                   324
# │ n image pairs                          2
# │ n subwindows in FOV                  162
# │ size(subwindows)                 (9, 18)
# │ M, N                            (64, 64)
# │ rhoI, rhoJ                      (40, 40)
# │ allocations [B]                194887232
# │ allocations [MB]                  194.89
# │ gc time [s]                    0.4375719
# │ gc stats            Base.GC_Diff(194887232, 1628, 0, 12845, 0, 0, 437571900, 2, 0)
# │ number of threads                      1
# │ Running on skylake CPU specs:
# │ Intel(R) Core(TM) i7-8550U CPU @ 1.80GHz:
# │        speed         user         nice          sys         idle          irq
# │ #1  1992 MHz     529203            0       569250     12619265        83109  ticks
# │ #2  1992 MHz     301984            0       293078     13122515         7984  ticks
# │ #3  1992 MHz     842031            0       473171     12402375        11562  ticks
# │ #4  1992 MHz     371906            0       283343     13062328         5750  ticks
# │ #5  1992 MHz     622953            0       421906     12672718         9703  ticks
# │ #6  1992 MHz     321984            0       199656     13195937         5562  ticks
# │ #7  1992 MHz     475171            0       342296     12900093        11593  ticks
# └ #8  1992 MHz     464656            0       281062     12971843         4671  ticks
# 5.0%┣██▏                                        ┫ 1/20 [00:00<Inf:Inf, InfGs/it]
# 10.0%┣████▊                                          ┫ 2/20 [00:01<00:13, 1it/s]
# 15.0%┣███████                                        ┫ 3/20 [00:01<00:09, 2it/s]
# 20.0%┣█████████▍                                     ┫ 4/20 [00:02<00:10, 2it/s]
# 25.0%┣███████████▊                                   ┫ 5/20 [00:02<00:08, 2it/s]
# 30.0%┣██████████████                                 ┫ 6/20 [00:03<00:07, 2it/s]
# 35.0%┣████████████████▌                              ┫ 7/20 [00:03<00:06, 2it/s]
# 40.0%┣██████████████████▉                            ┫ 8/20 [00:03<00:05, 2it/s]
# 45.0%┣█████████████████████▏                         ┫ 9/20 [00:03<00:05, 2it/s]
# 50.0%┣███████████████████████                       ┫ 10/20 [00:04<00:04, 2it/s]
# 55.0%┣█████████████████████████▎                    ┫ 11/20 [00:04<00:04, 2it/s]
# 60.0%┣███████████████████████████▋                  ┫ 12/20 [00:04<00:03, 2it/s]
# 65.0%┣██████████████████████████████                ┫ 13/20 [00:05<00:03, 3it/s]
# 70.0%┣████████████████████████████████▏             ┫ 14/20 [00:05<00:02, 3it/s]
# 75.0%┣██████████████████████████████████▌           ┫ 15/20 [00:06<00:02, 3it/s]
# 80.0%┣████████████████████████████████████▉         ┫ 16/20 [00:06<00:02, 3it/s]
# 85.0%┣███████████████████████████████████████       ┫ 17/20 [00:06<00:01, 3it/s]
# 90.0%┣█████████████████████████████████████████▍    ┫ 18/20 [00:07<00:01, 3it/s]
# 95.0%┣███████████████████████████████████████████▊  ┫ 19/20 [00:07<00:00, 3it/s]
# 100.0%┣█████████████████████████████████████████████┫ 20/20 [00:07<00:00, 3it/s]
# ┌ Info: Performance stats (MQD loop only)
# │ time [s]                       7.7968779
# │ subwins/s              20.77754738213869
# │ allocations [GB]                    1.95
# │ allocations [MB/subwin]               12.03
# │ time [m]                            0.13
# │ total n subwindows                  3240
# │ n image pairs                         20
# │ n subwindows in FOV                  162
# │ size(subwindows)                 (9, 18)
# │ M, N                            (64, 64)
# │ rhoI, rhoJ                      (40, 40)
# │ allocations [B]               1948924816
# │ allocations [MB]                 1948.92
# │ gc time [s]                    0.2192805
# │ gc stats            Base.GC_Diff(1948924816, 16280, 1, 129419, 3, 0, 219280500, 10, 0)
# │ number of threads                      1
# │ Running on skylake CPU specs:
# │ Intel(R) Core(TM) i7-8550U CPU @ 1.80GHz:
# │        speed         user         nice          sys         idle          irq
# │ #1  1992 MHz     531625            0       570843     12626078        83218  ticks
# │ #2  1992 MHz     302859            0       294281     13131265         7984  ticks
# │ #3  1992 MHz     844718            0       474781     12408906        11578  ticks
# │ #4  1992 MHz     373078            0       284125     13071203         5750  ticks
# │ #5  1992 MHz     624828            0       423109     12680468         9718  ticks
# │ #6  1992 MHz     323609            0       200687     13204109         5578  ticks
# │ #7  1992 MHz     477500            0       343875     12907015        11625  ticks
# └ #8  1992 MHz     466593            0       282562     12979234         4734  ticks
# 5.0%┣██▏                                        ┫ 1/20 [00:00<Inf:Inf, InfGs/it]
# 10.0%┣████▊                                          ┫ 2/20 [00:01<00:22, 1s/it]
# 15.0%┣███████                                        ┫ 3/20 [00:02<00:15, 1it/s]
# 20.0%┣█████████▍                                     ┫ 4/20 [00:03<00:13, 1it/s]
# 25.0%┣███████████▊                                   ┫ 5/20 [00:04<00:15, 1s/it]
# 30.0%┣██████████████                                 ┫ 6/20 [00:04<00:12, 1it/s]
# 35.0%┣████████████████▌                              ┫ 7/20 [00:05<00:11, 1it/s]
# 40.0%┣██████████████████▉                            ┫ 8/20 [00:06<00:10, 1it/s]
# 45.0%┣█████████████████████▏                         ┫ 9/20 [00:06<00:09, 1it/s]
# 50.0%┣███████████████████████                       ┫ 10/20 [00:07<00:07, 1it/s]
# 55.0%┣█████████████████████████▎                    ┫ 11/20 [00:07<00:06, 1it/s]
# 60.0%┣███████████████████████████▋                  ┫ 12/20 [00:07<00:05, 2it/s]
# 65.0%┣██████████████████████████████                ┫ 13/20 [00:08<00:04, 2it/s]
# 70.0%┣████████████████████████████████▏             ┫ 14/20 [00:08<00:04, 2it/s]
# 75.0%┣██████████████████████████████████▌           ┫ 15/20 [00:08<00:03, 2it/s]
# 80.0%┣████████████████████████████████████▉         ┫ 16/20 [00:08<00:02, 2it/s]
# 85.0%┣███████████████████████████████████████       ┫ 17/20 [00:09<00:02, 2it/s]
# 90.0%┣█████████████████████████████████████████▍    ┫ 18/20 [00:09<00:01, 2it/s]
# 95.0%┣███████████████████████████████████████████▊  ┫ 19/20 [00:09<00:01, 2it/s]
# 100.0%┣█████████████████████████████████████████████┫ 20/20 [00:10<00:00, 2it/s]
# ┌ Info: Performance stats (MQD loop only)
# │ time [s]                      10.1706489
# │ subwins/s             15.928187236902849
# │ allocations [GB]                    1.95
# │ allocations [MB/subwin]               12.03
# │ time [m]                            0.17
# │ total n subwindows                  3240
# │ n image pairs                         20
# │ n subwindows in FOV                  162
# │ size(subwindows)                 (9, 18)
# │ M, N                            (64, 64)
# │ rhoI, rhoJ                      (40, 40)
# │ allocations [B]               1948892784
# │ allocations [MB]                 1948.89
# │ gc time [s]                    2.0757705
# │ gc stats            Base.GC_Diff(1948892784, 16280, 1, 129136, 3, 0, 2075770500, 14, 2)
# │ number of threads                      1
# │ Running on skylake CPU specs:
# │ Intel(R) Core(TM) i7-8550U CPU @ 1.80GHz:
# │        speed         user         nice          sys         idle          irq
# │ #1  1992 MHz     534421            0       573453     12634328        83406  ticks
# │ #2  1992 MHz     304562            0       295703     13141796         8000  ticks
# │ #3  1992 MHz     847734            0       476781     12417546        11609  ticks
# │ #4  1992 MHz     375218            0       285640     13081203         5765  ticks
# │ #5  1992 MHz     627640            0       424906     12689500         9734  ticks
# │ #6  1992 MHz     325484            0       202656     13213921         5640  ticks
# │ #7  1992 MHz     480125            0       345734     12916187        11687  ticks
# └ #8  1992 MHz     469046            0       285093     12987906         4796  ticks
# 5.0%┣██▏                                        ┫ 1/20 [00:00<Inf:Inf, InfGs/it]
# 10.0%┣████▊                                          ┫ 2/20 [00:01<00:10, 2it/s]
# 15.0%┣███████                                        ┫ 3/20 [00:01<00:07, 2it/s]
# 20.0%┣█████████▍                                     ┫ 4/20 [00:01<00:06, 3it/s]
# 25.0%┣███████████▊                                   ┫ 5/20 [00:01<00:05, 3it/s]
# 30.0%┣██████████████                                 ┫ 6/20 [00:02<00:05, 3it/s]
# 35.0%┣████████████████▌                              ┫ 7/20 [00:02<00:04, 3it/s]
# 40.0%┣██████████████████▉                            ┫ 8/20 [00:02<00:04, 3it/s]
# 45.0%┣█████████████████████▏                         ┫ 9/20 [00:03<00:04, 3it/s]
# 50.0%┣███████████████████████                       ┫ 10/20 [00:03<00:03, 3it/s]
# 55.0%┣█████████████████████████▎                    ┫ 11/20 [00:03<00:03, 3it/s]
# 60.0%┣███████████████████████████▋                  ┫ 12/20 [00:04<00:03, 3it/s]
# 65.0%┣██████████████████████████████                ┫ 13/20 [00:04<00:02, 3it/s]
# 70.0%┣████████████████████████████████▏             ┫ 14/20 [00:04<00:02, 3it/s]
# 75.0%┣██████████████████████████████████▌           ┫ 15/20 [00:05<00:02, 3it/s]
# 80.0%┣████████████████████████████████████▉         ┫ 16/20 [00:05<00:01, 3it/s]
# 85.0%┣███████████████████████████████████████       ┫ 17/20 [00:05<00:01, 3it/s]
# 90.0%┣█████████████████████████████████████████▍    ┫ 18/20 [00:05<00:01, 3it/s]
# 95.0%┣███████████████████████████████████████████▊  ┫ 19/20 [00:06<00:00, 3it/s]
# 100.0%┣█████████████████████████████████████████████┫ 20/20 [00:06<00:00, 3it/s]
# ┌ Info: Performance stats (MQD loop only)
# │ time [s]                       6.4867993
# │ subwins/s             24.973795628300074
# │ allocations [GB]                    1.95
# │ allocations [MB/subwin]               12.03
# │ time [m]                            0.11
# │ total n subwindows                  3240
# │ n image pairs                         20
# │ n subwindows in FOV                  162
# │ size(subwindows)                 (9, 18)
# │ M, N                            (64, 64)
# │ rhoI, rhoJ                      (40, 40)
# │ allocations [B]               1948929792
# │ allocations [MB]                 1948.93
# │ gc time [s]                     0.141759
# │ gc stats            Base.GC_Diff(1948929792, 16280, 1, 129440, 5, 0, 141759000, 11, 0)
# │ number of threads                      1
# │ Running on skylake CPU specs:
# │ Intel(R) Core(TM) i7-8550U CPU @ 1.80GHz:
# │        speed         user         nice          sys         idle          irq
# │ #1  1992 MHz     536281            0       574500     12640828        83578  ticks
# │ #2  1992 MHz     305093            0       296265     13150109         8000  ticks
# │ #3  1992 MHz     849593            0       478109     12423765        11625  ticks
# │ #4  1992 MHz     375906            0       286046     13089515         5765  ticks
# │ #5  1992 MHz     628859            0       425484     12697125         9765  ticks
# │ #6  1992 MHz     326421            0       203000     13222046         5640  ticks
# │ #7  1992 MHz     481093            0       346625     12923734        11687  ticks
# └ #8  1992 MHz     470562            0       285531     12995359         4796  ticks
# 5.0%┣██▏                                        ┫ 1/20 [00:00<Inf:Inf, InfGs/it]
# 10.0%┣████▊                                          ┫ 2/20 [00:00<00:08, 2it/s]
# 15.0%┣███████                                        ┫ 3/20 [00:01<00:06, 3it/s]
# 20.0%┣█████████▍                                     ┫ 4/20 [00:01<00:06, 3it/s]
# 25.0%┣███████████▊                                   ┫ 5/20 [00:01<00:05, 3it/s]
# 30.0%┣██████████████                                 ┫ 6/20 [00:02<00:05, 3it/s]
# 35.0%┣████████████████▌                              ┫ 7/20 [00:02<00:04, 3it/s]
# 40.0%┣██████████████████▉                            ┫ 8/20 [00:02<00:04, 3it/s]
# 45.0%┣█████████████████████▏                         ┫ 9/20 [00:03<00:04, 3it/s]
# 50.0%┣███████████████████████                       ┫ 10/20 [00:03<00:03, 3it/s]
# 55.0%┣█████████████████████████▎                    ┫ 11/20 [00:03<00:03, 3it/s]
# 60.0%┣███████████████████████████▋                  ┫ 12/20 [00:04<00:03, 3it/s]
# 65.0%┣██████████████████████████████                ┫ 13/20 [00:04<00:02, 3it/s]
# 70.0%┣████████████████████████████████▏             ┫ 14/20 [00:04<00:02, 3it/s]
# 75.0%┣██████████████████████████████████▌           ┫ 15/20 [00:05<00:02, 3it/s]
# 80.0%┣████████████████████████████████████▉         ┫ 16/20 [00:05<00:01, 3it/s]
# 85.0%┣███████████████████████████████████████       ┫ 17/20 [00:05<00:01, 3it/s]
# 90.0%┣█████████████████████████████████████████▍    ┫ 18/20 [00:05<00:01, 3it/s]
# 95.0%┣███████████████████████████████████████████▊  ┫ 19/20 [00:06<00:00, 3it/s]
# 100.0%┣█████████████████████████████████████████████┫ 20/20 [00:06<00:00, 3it/s]
# ┌ Info: Performance stats (MQD loop only)
# │ time [s]                       6.1407029
# │ subwins/s              26.38134471543966
# │ allocations [GB]                    1.95
# │ allocations [MB/subwin]               12.03
# │ time [m]                             0.1
# │ total n subwindows                  3240
# │ n image pairs                         20
# │ n subwindows in FOV                  162
# │ size(subwindows)                 (9, 18)
# │ M, N                            (64, 64)
# │ rhoI, rhoJ                      (40, 40)
# │ allocations [B]               1948922288
# │ allocations [MB]                 1948.92
# │ gc time [s]                    0.4178648
# │ gc stats            Base.GC_Diff(1948922288, 16280, 1, 129460, 3, 0, 417864800, 13, 2)
# │ number of threads                      1
# │ Running on skylake CPU specs:
# │ Intel(R) Core(TM) i7-8550U CPU @ 1.80GHz:
# │        speed         user         nice          sys         idle          irq
# │ #1  1992 MHz     537937            0       575187     12647515        83687  ticks
# │ #2  1992 MHz     305609            0       296500     13158390         8000  ticks
# │ #3  1992 MHz     851296            0       478609     12430593        11640  ticks
# │ #4  1992 MHz     376406            0       286343     13097750         5765  ticks
# │ #5  1992 MHz     629546            0       426171     12704781         9765  ticks
# │ #6  1992 MHz     327062            0       203203     13230234         5640  ticks
# │ #7  1992 MHz     481703            0       346875     12931906        11718  ticks
# └ #8  1992 MHz     472234            0       286000     13002250         4875  ticks
# 5.0%┣██▏                                        ┫ 1/20 [00:00<Inf:Inf, InfGs/it]
# 10.0%┣████▊                                          ┫ 2/20 [00:01<00:09, 2it/s]
# 15.0%┣███████                                        ┫ 3/20 [00:01<00:07, 2it/s]
# 20.0%┣█████████▍                                     ┫ 4/20 [00:01<00:06, 3it/s]
# 25.0%┣███████████▊                                   ┫ 5/20 [00:01<00:05, 3it/s]
# 30.0%┣██████████████                                 ┫ 6/20 [00:02<00:05, 3it/s]
# 35.0%┣████████████████▌                              ┫ 7/20 [00:02<00:04, 3it/s]
# 40.0%┣██████████████████▉                            ┫ 8/20 [00:02<00:04, 3it/s]
# 45.0%┣█████████████████████▏                         ┫ 9/20 [00:03<00:04, 3it/s]
# 50.0%┣███████████████████████                       ┫ 10/20 [00:03<00:04, 3it/s]
# 55.0%┣█████████████████████████▎                    ┫ 11/20 [00:03<00:03, 3it/s]
# 60.0%┣███████████████████████████▋                  ┫ 12/20 [00:04<00:03, 3it/s]
# 65.0%┣██████████████████████████████                ┫ 13/20 [00:04<00:02, 3it/s]
# 70.0%┣████████████████████████████████▏             ┫ 14/20 [00:04<00:02, 3it/s]
# 75.0%┣██████████████████████████████████▌           ┫ 15/20 [00:05<00:02, 3it/s]
# 80.0%┣████████████████████████████████████▉         ┫ 16/20 [00:05<00:01, 3it/s]
# 85.0%┣███████████████████████████████████████       ┫ 17/20 [00:05<00:01, 3it/s]
# 90.0%┣█████████████████████████████████████████▍    ┫ 18/20 [00:06<00:01, 3it/s]
# 95.0%┣███████████████████████████████████████████▊  ┫ 19/20 [00:06<00:00, 3it/s]
# 100.0%┣█████████████████████████████████████████████┫ 20/20 [00:06<00:00, 3it/s]
# ┌ Info: Performance stats (MQD loop only)
# │ time [s]                        6.457976
# │ subwins/s             25.085258910841414
# │ allocations [GB]                    1.95
# │ allocations [MB/subwin]               12.03
# │ time [m]                            0.11
# │ total n subwindows                  3240
# │ n image pairs                         20
# │ n subwindows in FOV                  162
# │ size(subwindows)                 (9, 18)
# │ M, N                            (64, 64)
# │ rhoI, rhoJ                      (40, 40)
# │ allocations [B]               1948923040
# │ allocations [MB]                 1948.92
# │ gc time [s]                    0.1191482
# │ gc stats            Base.GC_Diff(1948923040, 16280, 1, 129480, 3, 0, 119148200, 11, 0)
# │ number of threads                      1
# │ Running on skylake CPU specs:
# │ Intel(R) Core(TM) i7-8550U CPU @ 1.80GHz:
# │        speed         user         nice          sys         idle          irq
# │ #1  1992 MHz
 2it/s]
# 15.0%┣███████                                        ┫ 3/20 [00:01<00:07, 2it/s]
# 20.0%┣█████████▍                                     ┫ 4/20 [00:01<00:06, 3it/s]
# 25.0%┣███████████▊                                   ┫ 5/20 [00:01<00:05, 3it/s]
# 30.0%┣██████████████                                 ┫ 6/20 [00:02<00:05, 3it/s]
# 35.0%┣████████████████▌                              ┫ 7/20 [00:02<00:04, 3it/s]
# 40.0%┣██████████████████▉                            ┫ 8/20 [00:02<00:04, 3it/s]
# 45.0%┣█████████████████████▏                         ┫ 9/20 [00:03<00:04, 3it/s]
# 50.0%┣███████████████████████                       ┫ 10/20 [00:03<00:03, 3it/s]
# 55.0%┣█████████████████████████▎                    ┫ 11/20 [00:03<00:03, 3it/s]
# 60.0%┣███████████████████████████▋                  ┫ 12/20 [00:04<00:03, 3it/s]
# 65.0%┣██████████████████████████████                ┫ 13/20 [00:04<00:02, 3it/s]
# 70.0%┣████████████████████████████████▏             ┫ 14/20 [00:04<00:02, 3it/s]
# 75.0%┣██████████████████████████████████▌           ┫ 15/20 [00:04<00:02, 3it/s]
# 80.0%┣████████████████████████████████████▉         ┫ 16/20 [00:05<00:01, 3it/s]
# 85.0%┣███████████████████████████████████████       ┫ 17/20 [00:05<00:01, 3it/s]
# 90.0%┣█████████████████████████████████████████▍    ┫ 18/20 [00:05<00:01, 3it/s]
# 95.0%┣███████████████████████████████████████████▊  ┫ 19/20 [00:05<00:00, 3it/s]
# 100.0%┣█████████████████████████████████████████████┫ 20/20 [00:06<00:00, 3it/s]
# ┌ Info: Performance stats (MQD loop only)
# │ time [s]                       5.9621583
# │ subwins/s             27.171368462323453
# │ allocations [GB]                    1.95
# │ allocations [MB/subwin]               12.03
# │ time [m]                             0.1
# │ total n subwindows                  3240
# │ n image pairs                         20
# │ n subwindows in FOV                  162
# │ size(subwindows)                 (9, 18)
# │ M, N                            (64, 64)
# │ rhoI, rhoJ                      (40, 40)
# │ allocations [B]               1948897344
# │ allocations [MB]                  1948.9
# │ gc time [s]                    0.2594147
# │ gc stats            Base.GC_Diff(1948897344, 16280, 1, 129187, 5, 0, 259414700, 13, 1)
# │ number of threads                      1
# │ Running on skylake CPU specs:
# │ Intel(R) Core(TM) i7-8550U CPU @ 1.80GHz:
# │        speed         user         nice          sys         idle          irq
# │ #1  1992 MHz     551750            0       581140     12682828        84265  ticks
# │ #2  1992 MHz     309250            0       298265     13208062         8093  ticks
# │ #3  1992 MHz     863906            0       482546     12469125        11734  ticks
# │ #4  1992 MHz     380484            0       288296     13146796         5828  ticks
# │ #5  1992 MHz     640734            0       429765     12745078         9984  ticks
# │ #6  1992 MHz     331171            0       204906     13279500         5671  ticks
# │ #7  1992 MHz     487093            0       349484     12978984        11812  ticks
# └ #8  1992 MHz     483140            0       289375     13043046         4921  ticks
# 5.0%┣██▏                                        ┫ 1/20 [00:00<Inf:Inf, InfGs/it]
# 10.0%┣████▊                                          ┫ 2/20 [00:00<00:08, 2it/s]
# 15.0%┣███████                                        ┫ 3/20 [00:01<00:06, 3it/s]
# 20.0%┣█████████▍                                     ┫ 4/20 [00:01<00:05, 3it/s]
# 25.0%┣███████████▊                                   ┫ 5/20 [00:01<00:05, 3it/s]
# 30.0%┣██████████████                                 ┫ 6/20 [00:02<00:04, 3it/s]
# 35.0%┣████████████████▌                              ┫ 7/20 [00:02<00:04, 3it/s]
# 40.0%┣██████████████████▉                            ┫ 8/20 [00:02<00:04, 3it/s]
# 45.0%┣█████████████████████▏                         ┫ 9/20 [00:02<00:03, 3it/s]
# 50.0%┣███████████████████████                       ┫ 10/20 [00:03<00:03, 3it/s]
# 55.0%┣█████████████████████████▎                    ┫ 11/20 [00:03<00:03, 3it/s]
# 60.0%┣███████████████████████████▋                  ┫ 12/20 [00:03<00:02, 3it/s]
# 65.0%┣██████████████████████████████                ┫ 13/20 [00:03<00:02, 3it/s]
# 70.0%┣████████████████████████████████▏             ┫ 14/20 [00:04<00:02, 3it/s]
# 75.0%┣██████████████████████████████████▌           ┫ 15/20 [00:04<00:01, 3it/s]
# 80.0%┣████████████████████████████████████▉         ┫ 16/20 [00:04<00:01, 3it/s]
# 85.0%┣███████████████████████████████████████       ┫ 17/20 [00:05<00:01, 3it/s]
# 90.0%┣█████████████████████████████████████████▍    ┫ 18/20 [00:05<00:01, 4it/s]
# 95.0%┣███████████████████████████████████████████▊  ┫ 19/20 [00:05<00:00, 4it/s]
# 100.0%┣█████████████████████████████████████████████┫ 20/20 [00:05<00:00, 3it/s]
# ┌ Info: Performance stats (MQD loop only)
# │ time [s]                       5.7667514
# │ subwins/s              28.09207277428328
# │ allocations [GB]                    1.95
# │ allocations [MB/subwin]               12.03
# │ time [m]                             0.1
# │ total n subwindows                  3240
# │ n image pairs                         20
# │ n subwindows in FOV                  162
# │ size(subwindows)                 (9, 18)
# │ M, N                            (64, 64)
# │ rhoI, rhoJ                      (40, 40)
# │ allocations [B]               1948900128
# │ allocations [MB]                  1948.9
# │ gc time [s]                    0.1018389
# │ gc stats            Base.GC_Diff(1948900128, 16280, 1, 129206, 5, 0, 101838900, 11, 0)
# │ number of threads                      1
# │ Running on skylake CPU specs:
# │ Intel(R) Core(TM) i7-8550U CPU @ 1.80GHz:
# │        speed         user         nice          sys         idle          irq
# │ #1  1992 MHz     553703            0       581718     12688890        84312  ticks
# │ #2  1992 MHz     309546            0       298375     13216250         8093  ticks
# │ #3  1992 MHz     864687            0       483125     12476359        11734  ticks
# │ #4  1992 MHz     380875            0       288531     13154750         5828  ticks
# │ #5  1992 MHz     641375            0       430062     12752734         9984  ticks
# │ #6  1992 MHz     331546            0       204968     13287640         5671  ticks
# │ #7  1992 MHz     487718            0       349593     12986843        11812  ticks
# └ #8  1992 MHz     484765            0       289828     13049546         4921  ticks
# 5.0%┣██▏                                        ┫ 1/20 [00:00<Inf:Inf, InfGs/it]
# 10.0%┣████▊                                          ┫ 2/20 [00:00<00:08, 2it/s]
# 15.0%┣███████                                        ┫ 3/20 [00:01<00:06, 3it/s]
# 20.0%┣█████████▍                                     ┫ 4/20 [00:01<00:05, 3it/s]
# 25.0%┣███████████▊                                   ┫ 5/20 [00:01<00:05, 3it/s]
# 30.0%┣██████████████                                 ┫ 6/20 [00:02<00:04, 3it/s]
# 35.0%┣████████████████▌                              ┫ 7/20 [00:02<00:04, 3it/s]
# 40.0%┣██████████████████▉                            ┫ 8/20 [00:02<00:04, 3it/s]
# 45.0%┣█████████████████████▏                         ┫ 9/20 [00:03<00:04, 3it/s]
# 50.0%┣███████████████████████                       ┫ 10/20 [00:03<00:03, 3it/s]
# 55.0%┣█████████████████████████▎                    ┫ 11/20 [00:03<00:03, 3it/s]
# 60.0%┣███████████████████████████▋                  ┫ 12/20 [00:04<00:03, 3it/s]
# 65.0%┣██████████████████████████████                ┫ 13/20 [00:04<00:02, 3it/s]
# 70.0%┣████████████████████████████████▏             ┫ 14/20 [00:04<00:02, 3it/s]
# 75.0%┣██████████████████████████████████▌           ┫ 15/20 [00:04<00:02, 3it/s]
# 80.0%┣████████████████████████████████████▉         ┫ 16/20 [00:05<00:01, 3it/s]
# 85.0%┣███████████████████████████████████████       ┫ 17/20 [00:05<00:01, 3it/s]
# 90.0%┣█████████████████████████████████████████▍    ┫ 18/20 [00:05<00:01, 3it/s]
# 95.0%┣███████████████████████████████████████████▊  ┫ 19/20 [00:06<00:00, 3it/s]
# 100.0%┣█████████████████████████████████████████████┫ 20/20 [00:06<00:00, 3it/s]
# ┌ Info: Performance stats (MQD loop only)
# │ time [s]                       6.0787591
# │ subwins/s              26.65017602029993
# │ allocations [GB]                    1.95
# │ allocations [MB/subwin]               12.03
# │ time [m]                             0.1
# │ total n subwindows                  3240
# │ n image pairs                         20
# │ n subwindows in FOV                  162
# │ size(subwindows)                 (9, 18)
# │ M, N                            (64, 64)
# │ rhoI, rhoJ                      (40, 40)
# │ allocations [B]               1948915888
# │ allocations [MB]                 1948.92
# │ gc time [s]                    0.4410472
# │ gc stats            Base.GC_Diff(1948915888, 16280, 1, 129367, 3, 0, 441047200, 13, 2)
# │ number of threads                      1
# │ Running on skylake CPU specs:
# │ Intel(R) Core(TM) i7-8550U CPU @ 1.80GHz:
# │        speed         user         nice          sys         idle          irq
# │ #1  1992 MHz     555500            0       582250     12695562        84375  ticks
# │ #2  1992 MHz     310250            0       298515     13224406         8093  ticks
# │ #3  1992 MHz     865968            0       483656     12483546        11750  ticks
# │ #4  1992 MHz     381718            0       288734     13162718         5828  ticks
# │ #5  1992 MHz     642140            0       430468     12760562        10000  ticks
# │ #6  1992 MHz     331765            0       205093     13296312         5703  ticks
# │ #7  1992 MHz     488312            0       349718     12995125        11812  ticks
# └ #8  1992 MHz     486578            0       290312     13056265         4921  ticks
# 5.0%┣██▏                                        ┫ 1/20 [00:00<Inf:Inf, InfGs/it]
# 10.0%┣████▊                                          ┫ 2/20 [00:00<00:08, 2it/s]
# 15.0%┣███████                                        ┫ 3/20 [00:01<00:06, 3it/s]
# 20.0%┣█████████▍                                     ┫ 4/20 [00:01<00:05, 3it/s]
# 25.0%┣███████████▊                                   ┫ 5/20 [00:01<00:05, 3it/s]
# 30.0%┣██████████████                                 ┫ 6/20 [00:02<00:05, 3it/s]
# 35.0%┣████████████████▌                              ┫ 7/20 [00:02<00:04, 3it/s]
# 40.0%┣██████████████████▉                            ┫ 8/20 [00:02<00:04, 3it/s]
# 45.0%┣█████████████████████▏                         ┫ 9/20 [00:02<00:03, 3it/s]
# 50.0%┣███████████████████████                       ┫ 10/20 [00:03<00:03, 3it/s]
# 55.0%┣█████████████████████████▎                    ┫ 11/20 [00:03<00:03, 3it/s]
# 60.0%┣███████████████████████████▋                  ┫ 12/20 [00:03<00:02, 3it/s]
# 65.0%┣██████████████████████████████                ┫ 13/20 [00:04<00:02, 3it/s]
# 70.0%┣████████████████████████████████▏             ┫ 14/20 [00:04<00:02, 3it/s]
# 75.0%┣██████████████████████████████████▌           ┫ 15/20 [00:04<00:02, 3it/s]
# 80.0%┣████████████████████████████████████▉         ┫ 16/20 [00:05<00:01, 3it/s]
# 85.0%┣███████████████████████████████████████       ┫ 17/20 [00:05<00:01, 3it/s]
# 90.0%┣█████████████████████████████████████████▍    ┫ 18/20 [00:05<00:01, 3it/s]
# 95.0%┣███████████████████████████████████████████▊  ┫ 19/20 [00:05<00:00, 3it/s]
# 100.0%┣█████████████████████████████████████████████┫ 20/20 [00:06<00:00, 3it/s]
# ...
# │ #7  1992 MHz     500484            0       354984     13129203        12031  ticks
# └ #8  1992 MHz     513531            0       297640     13173500         5234  ticks
# 5.3%┣██▎                                        ┫ 1/19 [00:00<Inf:Inf, InfGs/it]
# 10.5%┣█████                                          ┫ 2/19 [00:01<00:10, 2it/s]
# 15.8%┣███████▍                                       ┫ 3/19 [00:01<00:07, 2it/s]
# 21.1%┣██████████                                     ┫ 4/19 [00:01<00:06, 2it/s]
# 26.3%┣████████████▍                                  ┫ 5/19 [00:02<00:05, 3it/s]
# 31.6%┣██████████████▉                                ┫ 6/19 [00:02<00:05, 3it/s]
# 36.8%┣█████████████████▎                             ┫ 7/19 [00:02<00:04, 3it/s]
# 42.1%┣███████████████████▉                           ┫ 8/19 [00:02<00:04, 3it/s]
# 47.4%┣██████████████████████▎                        ┫ 9/19 [00:03<00:04, 3it/s]
# 52.6%┣████████████████████████▏                     ┫ 10/19 [00:03<00:03, 3it/s]
# 57.9%┣██████████████████████████▋                   ┫ 11/19 [00:04<00:03, 3it/s]
# 63.2%┣█████████████████████████████                 ┫ 12/19 [00:04<00:03, 3it/s]
# 68.4%┣███████████████████████████████▌              ┫ 13/19 [00:04<00:02, 3it/s]
# 73.7%┣██████████████████████████████████            ┫ 14/19 [00:04<00:02, 3it/s]
# 78.9%┣████████████████████████████████████▎         ┫ 15/19 [00:05<00:01, 3it/s]
# 84.2%┣██████████████████████████████████████▊       ┫ 16/19 [00:05<00:01, 3it/s]
# 89.5%┣█████████████████████████████████████████▏    ┫ 17/19 [00:05<00:01, 3it/s]
# 94.7%┣███████████████████████████████████████████▋  ┫ 18/19 [00:06<00:00, 3it/s]
# 100.0%┣█████████████████████████████████████████████┫ 19/19 [00:06<00:00, 3it/s]
# ┌ Info: Performance stats (MQD loop only)
# │ time [s]                       6.0996018
# │ subwins/s              26.55911079310128
# │ allocations [GB]                    1.85
# │ allocations [MB/subwin]               11.43
# │ time [m]                             0.1
# │ total n subwindows                  3078
# │ n image pairs                         19
# │ n subwindows in FOV                  162
# │ size(subwindows)                 (9, 18)
# │ M, N                            (64, 64)
# │ rhoI, rhoJ                      (40, 40)
# │ allocations [B]               1851462400
# │ allocations [MB]                 1851.46
# │ gc time [s]                    0.3884131
# │ gc stats            Base.GC_Diff(1851462400, 15466, 1, 122886, 3, 0, 388413100, 12, 2)
# │ number of threads                      1
# │ Running on skylake CPU specs:
# │ Intel(R) Core(TM) i7-8550U CPU @ 1.80GHz:
# │        speed         user         nice          sys         idle          irq
# │ #1  1992 MHz     594031            0       595078     12804625        85968  ticks
# │ #2  1992 MHz     320093            0       302968     13370531         8187  ticks
# │ #3  1992 MHz     891859            0       493593     12608140        12015  ticks
# │ #4  1992 MHz     393031            0       293796     13306765         5921  ticks
# │ #5  1992 MHz     654656            0       438890     12900046        10125  ticks
# │ #6  1992 MHz     339375            0       208671     13445546         5796  ticks
# │ #7  1992 MHz     501093            0       355312     13137171        12046  ticks
# └ #8  1992 MHz     514562            0       298171     13180843         5234  ticks
# 5.3%┣██▎                                        ┫ 1/19 [00:00<Inf:Inf, InfGs/it]
# 10.5%┣█████                                          ┫ 2/19 [00:00<00:08, 2it/s]
# 15.8%┣███████▍                                       ┫ 3/19 [00:01<00:06, 3it/s]
# 21.1%┣██████████                                     ┫ 4/19 [00:01<00:05, 3it/s]
# 26.3%┣████████████▍                                  ┫ 5/19 [00:01<00:05, 3it/s]
# 31.6%┣██████████████▉                                ┫ 6/19 [00:02<00:04, 3it/s]
# 36.8%┣█████████████████▎                             ┫ 7/19 [00:02<00:04, 3it/s]
# 42.1%┣███████████████████▉                           ┫ 8/19 [00:02<00:03, 3it/s]
# 47.4%┣██████████████████████▎                        ┫ 9/19 [00:02<00:03, 3it/s]
# 52.6%┣████████████████████████▏                     ┫ 10/19 [00:03<00:03, 3it/s]
# 57.9%┣██████████████████████████▋                   ┫ 11/19 [00:03<00:02, 3it/s]
# 63.2%┣█████████████████████████████                 ┫ 12/19 [00:03<00:02, 3it/s]
# 68.4%┣███████████████████████████████▌              ┫ 13/19 [00:04<00:02, 3it/s]
# 73.7%┣██████████████████████████████████            ┫ 14/19 [00:04<00:02, 3it/s]
# 78.9%┣████████████████████████████████████▎         ┫ 15/19 [00:04<00:01, 3it/s]
# 84.2%┣██████████████████████████████████████▊       ┫ 16/19 [00:05<00:01, 3it/s]
# 89.5%┣█████████████████████████████████████████▏    ┫ 17/19 [00:05<00:01, 3it/s]
# 94.7%┣███████████████████████████████████████████▋  ┫ 18/19 [00:05<00:00, 3it/s]
# 100.0%┣█████████████████████████████████████████████┫ 19/19 [00:05<00:00, 3it/s]
# ┌ Info: Performance stats (MQD loop only)
# │ time [s]                       5.7627813
# │ subwins/s             28.111425988003397
# │ allocations [GB]                    1.85
# │ allocations [MB/subwin]               11.43
# │ time [m]                             0.1
# │ total n subwindows                  3078
# │ n image pairs                         19
# │ n subwindows in FOV                  162
# │ size(subwindows)                 (9, 18)
# │ M, N                            (64, 64)
# │ rhoI, rhoJ                      (40, 40)
# │ allocations [B]               1851460768
# │ allocations [MB]                 1851.46
# │ gc time [s]                    0.0908895
# │ gc stats            Base.GC_Diff(1851460768, 15466, 2, 122738, 5, 0, 90889500, 11, 0)
# │ number of threads                      1
# │ Running on skylake CPU specs:
# │ Intel(R) Core(TM) i7-8550U CPU @ 1.80GHz:
# │        speed         user         nice          sys         idle          irq
# │ #1  1992 MHz     595265            0       595765     12811312        86031  ticks
# │ #2  1992 MHz     320875            0       303234     13378093         8187  ticks
# │ #3  1992 MHz     893359            0       494125     12614703        12015  ticks
# │ #4  1992 MHz     393593            0       294234     13314375         5921  ticks
# │ #5  1992 MHz     655703            0       439390     12907109        10125  ticks
# │ #6  1992 MHz     340093            0       208906     13453187         5812  ticks
# │ #7  1992 MHz     501718            0       355750     13144718        12062  ticks
# └ #8  1992 MHz     516015            0       298609     13187562         5250  ticks
# 5.3%┣██▎                                        ┫ 1/19 [00:00<Inf:Inf, InfGs/it]
# 10.5%┣█████                                          ┫ 2/19 [00:00<00:08, 2it/s]
# 15.8%┣███████▍                                       ┫ 3/19 [00:01<00:06, 3it/s]
# 21.1%┣██████████                                     ┫ 4/19 [00:01<00:05, 3it/s]
# 26.3%┣████████████▍                                  ┫ 5/19 [00:01<00:05, 3it/s]
# 31.6%┣██████████████▉                                ┫ 6/19 [00:02<00:04, 3it/s]
# 36.8%┣█████████████████▎                             ┫ 7/19 [00:02<00:04, 3it/s]
# 42.1%┣███████████████████▉                           ┫ 8/19 [00:02<00:03, 3it/s]
# 47.4%┣██████████████████████▎                        ┫ 9/19 [00:03<00:03, 3it/s]
# 52.6%┣████████████████████████▏                     ┫ 10/19 [00:03<00:03, 3it/s]
# 57.9%┣██████████████████████████▋                   ┫ 11/19 [00:03<00:02, 3it/s]
# 63.2%┣█████████████████████████████                 ┫ 12/19 [00:03<00:02, 3it/s]
# 68.4%┣███████████████████████████████▌              ┫ 13/19 [00:04<00:02, 3it/s]
# 73.7%┣██████████████████████████████████            ┫ 14/19 [00:04<00:02, 3it/s]
# 78.9%┣████████████████████████████████████▎         ┫ 15/19 [00:04<00:01, 3it/s]
# 84.2%┣██████████████████████████████████████▊       ┫ 16/19 [00:05<00:01, 3it/s]
# 89.5%┣█████████████████████████████████████████▏    ┫ 17/19 [00:05<00:01, 3it/s]
# 94.7%┣███████████████████████████████████████████▋  ┫ 18/19 [00:05<00:00, 3it/s]
# 100.0%┣█████████████████████████████████████████████┫ 19/19 [00:05<00:00, 3it/s]
# ┌ Info: Performance stats (MQD loop only)
# │ time [s]                       5.6728317
# │ subwins/s             28.557166608697383
# │ allocations [GB]                    1.85
# │ allocations [MB/subwin]               11.43
# │ time [m]                            0.09
# │ total n subwindows                  3078
# │ n image pairs                         19
# │ n subwindows in FOV                  162
# │ size(subwindows)                 (9, 18)
# │ M, N                            (64, 64)
# │ rhoI, rhoJ                      (40, 40)
# │ allocations [B]               1851467728
# │ allocations [MB]                 1851.47
# │ gc time [s]                    0.3729938
# │ gc stats            Base.GC_Diff(1851467728, 15466, 1, 122928, 3, 0, 372993800, 12, 2)
# │ number of threads                      1
# │ Running on skylake CPU specs:
# │ Intel(R) Core(TM) i7-8550U CPU @ 1.80GHz:
# │        speed         user         nice          sys         idle          irq
# │ #1  1992 MHz     597562            0       596328     12816921        86093  ticks
# │ #2  1992 MHz     321078            0       303421     13386171         8203  ticks
# │ #3  1992 MHz     894250            0       494578     12621843        12031  ticks
# │ #4  1992 MHz     394312            0       294484     13321875         5921  ticks
# │ #5  1992 MHz     656218            0       439718     12914734        10140  ticks
# │ #6  1992 MHz     340453            0       209031     13461187         5812  ticks
# │ #7  1992 MHz     502656            0       355984     13152015        12078  ticks
# └ #8  1992 MHz     517765            0       299171     13193718         5265  ticks
# 5.3%┣██▎                                        ┫ 1/19 [00:00<Inf:Inf, InfGs/it]
# 10.5%┣█████                                          ┫ 2/19 [00:00<00:08, 2it/s]
# 15.8%┣███████▍                                       ┫ 3/19 [00:01<00:06, 3it/s]
# 21.1%┣██████████                                     ┫ 4/19 [00:01<00:05, 3it/s]
# 26.3%┣████████████▍                                  ┫ 5/19 [00:01<00:05, 3it/s]
# 31.6%┣██████████████▉                                ┫ 6/19 [00:02<00:04, 3it/s]
# 36.8%┣█████████████████▎                             ┫ 7/19 [00:02<00:04, 3it/s]
# 42.1%┣███████████████████▉                           ┫ 8/19 [00:02<00:03, 3it/s]
# 47.4%┣██████████████████████▎                        ┫ 9/19 [00:02<00:03, 3it/s]
# 52.6%┣████████████████████████▏                     ┫ 10/19 [00:03<00:03, 3it/s]
# 57.9%┣██████████████████████████▋                   ┫ 11/19 [00:03<00:02, 3it/s]
# 63.2%┣█████████████████████████████                 ┫ 12/19 [00:03<00:02, 3it/s]
# 68.4%┣███████████████████████████████▌              ┫ 13/19 [00:04<00:02, 3it/s]
# 73.7%┣██████████████████████████████████            ┫ 14/19 [00:04<00:01, 3it/s]
# 78.9%┣████████████████████████████████████▎         ┫ 15/19 [00:04<00:01, 3it/s]
# 84.2%┣██████████████████████████████████████▊       ┫ 16/19 [00:04<00:01, 3it/s]
# 89.5%┣█████████████████████████████████████████▏    ┫ 17/19 [00:05<00:01, 3it/s]
# 94.7%┣███████████████████████████████████████████▋  ┫ 18/19 [00:05<00:00, 3it/s]
# 100.0%┣█████████████████████████████████████████████┫ 19/19 [00:05<00:00, 3it/s]
# ┌ Info: Performance stats (MQD loop only)
# │ time [s]                       5.5831505
# │ subwins/s               29.0158755347899
# │ allocations [GB]                    1.85
# │ allocations [MB/subwin]               11.43
# │ time [m]                            0.09
# │ total n subwindows                  3078
# │ n image pairs                         19
# │ n subwindows in FOV                  162
# │ size(subwindows)                 (9, 18)
# │ M, N                            (64, 64)
# │ rhoI, rhoJ                      (40, 40)
# │ allocations [B]               1851466096
# │ allocations [MB]                 1851.47
# │ gc time [s]                    0.0883735
# │ gc stats            Base.GC_Diff(1851466096, 15466, 1, 122832, 3, 0, 88373500, 11, 0)
# │ number of threads                      1
# │ Running on skylake CPU specs:
# │ Intel(R) Core(TM) i7-8550U CPU @ 1.80GHz:
# │        speed         user         nice          sys         idle          irq
# │ #1  1992 MHz     599015            0       596968     12823000        86125  ticks
# │ #2  1992 MHz     321546            0       303484     13393828         8218  ticks
# │ #3  1992 MHz     896421            0       494718     12627718        12046  ticks
# │ #4  1992 MHz     394875            0       294562     13329390         5921  ticks
# │ #5  1992 MHz     657109            0       440015     12921734        10140  ticks
# │ #6  1992 MHz     345562            0       209171     13464125         5828  ticks
# │ #7  1992 MHz     504015            0       356156     13158671        12078  ticks
# └ #8  1992 MHz     519156            0       299359     13200328         5265  ticks
# 5.3%┣██▎                                        ┫ 1/19 [00:00<Inf:Inf, InfGs/it]
# 10.5%┣█████                                          ┫ 2/19 [00:00<00:08, 2it/s]
# 15.8%┣███████▍                                       ┫ 3/19 [00:01<00:06, 3it/s]
# 21.1%┣██████████                                     ┫ 4/19 [00:01<00:05, 3it/s]
# 26.3%┣████████████▍                                  ┫ 5/19 [00:01<00:05, 3it/s]
# 31.6%┣██████████████▉                                ┫ 6/19 [00:02<00:04, 3it/s]
# 36.8%┣█████████████████▎                             ┫ 7/19 [00:02<00:04, 3it/s]
# 42.1%┣███████████████████▉                           ┫ 8/19 [00:02<00:03, 3it/s]
# 47.4%┣██████████████████████▎                        ┫ 9/19 [00:03<00:03, 3it/s]
# 52.6%┣████████████████████████▏                     ┫ 10/19 [00:03<00:03, 3it/s]
# 57.9%┣██████████████████████████▋                   ┫ 11/19 [00:03<00:03, 3it/s]
# 63.2%┣█████████████████████████████                 ┫ 12/19 [00:04<00:02, 3it/s]
# 68.4%┣███████████████████████████████▌              ┫ 13/19 [00:04<00:02, 3it/s]
# 73.7%┣██████████████████████████████████            ┫ 14/19 [00:04<00:02, 3it/s]
# 78.9%┣████████████████████████████████████▎         ┫ 15/19 [00:04<00:01, 3it/s]
# 84.2%┣██████████████████████████████████████▊       ┫ 16/19 [00:05<00:01, 3it/s]
# 89.5%┣█████████████████████████████████████████▏    ┫ 17/19 [00:05<00:01, 3it/s]
# 94.7%┣███████████████████████████████████████████▋  ┫ 18/19 [00:05<00:00, 3it/s]
# 100.0%┣█████████████████████████████████████████████┫ 19/19 [00:06<00:00, 3it/s]
# ┌ Info: Performance stats (MQD loop only)
# │ time [s]                       5.8362067
# │ subwins/s             27.757755735416293
# │ allocations [GB]                    1.85
# │ allocations [MB/subwin]               11.43
# │ time [m]                             0.1
# │ total n subwindows                  3078
# │ n image pairs                         19
# │ n subwindows in FOV                  162
# │ size(subwindows)                 (9, 18)
# │ M, N                            (64, 64)
# │ rhoI, rhoJ                      (40, 40)
# │ allocations [B]               1851440656
# │ allocations [MB]                 1851.44
# │ gc time [s]                    0.3980949
# │ gc stats            Base.GC_Diff(1851440656, 15466, 1, 122679, 3, 0, 398094900, 12, 2)
# │ number of threads                      1
# │ Running on skylake CPU specs:
# │ Intel(R) Core(TM) i7-8550U CPU @ 1.80GHz:
# │        speed         user         nice          sys         idle          irq
# │ #1  1992 MHz     600656            0       597734     12829078        86171  ticks
# │ #2  1992 MHz     321875            0       303687     13401765         8234  ticks
# │ #3  1992 MHz     898734            0       495000     12633593        12046  ticks
# │ #4  1992 MHz     395640            0       294734     13336953         5921  ticks
# │ #5  1992 MHz     662218            0       440406     12924703        10140  ticks
# │ #6  1992 MHz     346281            0       209265     13471781         5828  ticks
# │ #7  1992 MHz     505234            0       356578     13165500        12093  ticks
# └ #8  1992 MHz     520921            0       299609     13206781         5265  ticks

# %%
# Downstream IRQIV averaging
Pkg.activate(expanduser("~/.julia/dev/IRQIV/")) # path to IRQIV directory
using IRQIV


###############################################################################

###############################################################################
const M=64 # subwindow dims - horiz, N = vert.
const N=64
const rhoI = 40 # how far away to search (+/-) - i=horiz, j= vert
const rhoJ = 40 # Set these to visual estimates - plot one pair
MQD_parameters = (M=M, N=N, rhoI=rhoI, rhoJ=rhoJ)
###############################################################################


###############################################################################
DtFrames = 1                    # Δt, frames (ATS 3116 is at 10Hz)
data_output_rate_frames = 150    # difference between I1 sequence, frames - time sep of output
nImagePairs = 20 # can set to inf - all frames in file
# Can test on 10 pairs & look at histogram of displacements
###############################################################################


###############################################################################
# Load IR images:
I1inds = range(1, step=data_output_rate_frames, length=nImagePairs)
I2inds = I1inds .+ DtFrames

Nfiles = 20

meanmagsds = fill(NaN, Nfiles)
for f = 1:Nfiles
    file = f+3485
    FLIR_filename = joinpath(raw"D:\CNRD_IR", # from RAID here - deeper file structure than NVME
                         "Rec-DeFreesLab_-00" * string.(file) * ".ats")
    ats_year = 2022
    @assert isfile(FLIR_filename)
    I1images = LoadATSImageSequence(FLIR_filename, I1inds, ats_year)
    I2images = LoadATSImageSequence(FLIR_filename, I2inds, ats_year)

    if any(isnuc(I1images.Headers)) || any(isnuc(I2images.Headers))
        nuc_frames = isnuc(I1images.Headers) .| isnuc(I2images.Headers)
        I1inds = I1inds[.!( isnuc(I1images.Headers) .| isnuc(I2images.Headers) )]
        I2inds = I2inds[.!( isnuc(I1images.Headers) .| isnuc(I2images.Headers) )]
        I1images = LoadATSImageSequence(FLIR_filename, I1inds, ats_year)
        I2images = LoadATSImageSequence(FLIR_filename, I2inds, ats_year)
    end

    subwincorners = CartesianIndices(( (N+rhoI):N:(size(I1images,1)-(N+rhoI+1)),
                                   (M+rhoJ):M:(size(I1images,2)-(M+rhoJ+1)) ))

    MQD_variables = initialize_MQD(I1images,
                                   I2images,
                                   subwincorners,
                                   N, M,
                                   rhoI, rhoJ)                              

    subpix_shifts_i, subpix_shifts_j, performance_message = perform_MQD(
        I1images, I2images, subwincorners, MQD_variables, MQD_parameters);
    ###############################################################################
    jmean = Statistics.mean(subpix_shifts_j[:,:,:], dims=3)
    imean = Statistics.mean(subpix_shifts_i[:,:,:], dims=3)
    jmean = dropdims(jmean, dims=3)
    imean = dropdims(imean, dims=3)
    meanmagsds[f] = Statistics.mean(hypot.(jmean, imean))

    i = [ x[1] for x in Tuple.(subwincorners)]
    j = [ x[2] for x in Tuple.(subwincorners)]
    
    plt.close("all")
    fig,ax = plt.subplots()
    im = ax.imshow(I1images[:,:,1], alpha=0.3, vmin=8700, vmax=11800)
    q = ax.quiver(j,i, jmean, imean, angles="xy")
    # ax.invert_yaxis()
    
    # Look at histogram of displacements
    fig, ax = plt.subplots()
    h1 = ax.hist(vec(subpix_shifts_i), 100, label="i", alpha=0.4);
    h2 = ax.hist(vec(subpix_shifts_j), 100, label="j", alpha=0.4);
    plt.legend()
    plt.show()
end
# Out:
#   Activating new environment at `C:\Users\evanh\Box\Cornell\CACO\2022\Analysis\IRQIV.jl\CACO_2022_jl\~\.julia\dev\IRQIV\Project.toml`
# 5.0%┣██▏                                        ┫ 1/20 [00:00<Inf:Inf, InfGs/it]
# 10.0%┣████▊                                          ┫ 2/20 [00:00<00:05, 4it/s]
# 15.0%┣███████                                        ┫ 3/20 [00:01<00:05, 4it/s]
# 20.0%┣█████████▍                                     ┫ 4/20 [00:01<00:04, 4it/s]
# 25.0%┣███████████▊                                   ┫ 5/20 [00:01<00:04, 4it/s]
# 30.0%┣██████████████                                 ┫ 6/20 [00:01<00:04, 4it/s]
# 35.0%┣████████████████▌                              ┫ 7/20 [00:02<00:04, 4it/s]
# 40.0%┣██████████████████▉                            ┫ 8/20 [00:02<00:03, 4it/s]
# 45.0%┣█████████████████████▏                         ┫ 9/20 [00:02<00:03, 4it/s]
# 50.0%┣███████████████████████                       ┫ 10/20 [00:02<00:03, 4it/s]
# 55.0%┣█████████████████████████▎                    ┫ 11/20 [00:03<00:02, 4it/s]
# 60.0%┣███████████████████████████▋                  ┫ 12/20 [00:03<00:02, 4it/s]
# 65.0%┣██████████████████████████████                ┫ 13/20 [00:03<00:02, 4it/s]
# 70.0%┣████████████████████████████████▏             ┫ 14/20 [00:04<00:02, 4it/s]
# 75.0%┣██████████████████████████████████▌           ┫ 15/20 [00:04<00:01, 4it/s]
# 80.0%┣████████████████████████████████████▉         ┫ 16/20 [00:04<00:01, 4it/s]
# 85.0%┣███████████████████████████████████████       ┫ 17/20 [00:04<00:01, 4it/s]
# 90.0%┣█████████████████████████████████████████▍    ┫ 18/20 [00:05<00:01, 4it/s]
# 95.0%┣███████████████████████████████████████████▊  ┫ 19/20 [00:05<00:00, 4it/s]
# 100.0%┣█████████████████████████████████████████████┫ 20/20 [00:05<00:00, 4it/s]
# ┌ Info: Performance stats (MQD loop only)
# │ time [s]                        5.480028
# │ subwins/s             29.561892749453104
# │ allocations [GB]                    1.95
# │ allocations [MB/subwin]               12.03
# │ time [m]                            0.09
# │ total n subwindows                  3240
# │ n image pairs                         20
# │ n subwindows in FOV                  162
# │ size(subwindows)                 (9, 18)
# │ M, N                            (64, 64)
# │ rhoI, rhoJ                      (40, 40)
# │ allocations [B]               1
 12, 2)
# │ number of threads                      1
# │ Running on skylake CPU specs:
# │ Intel(R) Core(TM) i7-8550U CPU @ 1.80GHz:
# │        speed         user         nice          sys         idle          irq
# │ #1  1992 MHz     622046            0       602250     12889953        86812  ticks
# │ #2  1992 MHz     324750            0       304937     13484421         8296  ticks
# │ #3  1992 MHz     906187            0       498234     12709687        12062  ticks
# │ #4  1992 MHz     400812            0       296031     13417265         5968  ticks
# │ #5  1992 MHz     666843            0       443437     13003828        10218  ticks
# │ #6  1992 MHz     350281            0       210390     13553437         5843  ticks
# │ #7  1992 MHz     510218            0       358531     13245343        12187  ticks
# └ #8  1992 MHz     536250            0       303171     13274671         5343  ticks
# 5.0%┣██▏                                        ┫ 1/20 [00:00<Inf:Inf, InfGs/it]
# 10.0%┣████▊                                          ┫ 2/20 [00:00<00:08, 2it/s]
# 15.0%┣███████                                        ┫ 3/20 [00:01<00:06, 3it/s]
# 20.0%┣█████████▍                                     ┫ 4/20 [00:01<00:05, 3it/s]
# 25.0%┣███████████▊                                   ┫ 5/20 [00:01<00:04, 3it/s]
# 30.0%┣██████████████                                 ┫ 6/20 [00:01<00:04, 3it/s]
# 35.0%┣████████████████▌                              ┫ 7/20 [00:02<00:04, 3it/s]
# 40.0%┣██████████████████▉                            ┫ 8/20 [00:02<00:03, 4it/s]
# 45.0%┣█████████████████████▏                         ┫ 9/20 [00:02<00:03, 4it/s]
# 50.0%┣███████████████████████                       ┫ 10/20 [00:03<00:03, 4it/s]
# 55.0%┣█████████████████████████▎                    ┫ 11/20 [00:03<00:03, 4it/s]
# 60.0%┣███████████████████████████▋                  ┫ 12/20 [00:03<00:02, 4it/s]
# 65.0%┣██████████████████████████████                ┫ 13/20 [00:03<00:02, 4it/s]
# 70.0%┣████████████████████████████████▏             ┫ 14/20 [00:04<00:02, 4it/s]
# 75.0%┣██████████████████████████████████▌           ┫ 15/20 [00:04<00:01, 4it/s]
# 80.0%┣████████████████████████████████████▉         ┫ 16/20 [00:04<00:01, 4it/s]
# 85.0%┣███████████████████████████████████████       ┫ 17/20 [00:04<00:01, 4it/s]
# 90.0%┣█████████████████████████████████████████▍    ┫ 18/20 [00:05<00:01, 4it/s]
# 95.0%┣███████████████████████████████████████████▊  ┫ 19/20 [00:05<00:00, 4it/s]
# 100.0%┣█████████████████████████████████████████████┫ 20/20 [00:05<00:00, 3it/s]
# ┌ Info: Performance stats (MQD loop only)
# │ time [s]                       5.7106916
# │ subwins/s             28.367842521911008
# │ allocations [GB]                    1.95
# │ allocations [MB/subwin]               12.03
# │ time [m]                             0.1
# │ total n subwindows                  3240
# │ n image pairs                         20
# │ n subwindows in FOV                  162
# │ size(subwindows)                 (9, 18)
# │ M, N                            (64, 64)
# │ rhoI, rhoJ                      (40, 40)
# │ allocations [B]               1948924064
# │ allocations [MB]                 1948.92
# │ gc time [s]                     0.095065
# │ gc stats            Base.GC_Diff(1948924064, 16280, 1, 129455, 3, 0, 95065000, 11, 0)
# │ number of threads                      1
# │ Running on skylake CPU specs:
# │ Intel(R) Core(TM) i7-8550U CPU @ 1.80GHz:
# │        speed         user         nice          sys         idle          irq
# │ #1  1992 MHz     623875            0       602781     12896218        86859  ticks
# │ #2  1992 MHz     325140            0       305156     13492437         8312  ticks
# │ #3  1992 MHz     906968            0       498515     12717250        12093  ticks
# │ #4  1992 MHz     401328            0       296218     13425187         5968  ticks
# │ #5  1992 MHz     667359            0       443875     13011500        10218  ticks
# │ #6  1992 MHz     350734            0       210468     13561531         5843  ticks
# │ #7  1992 MHz     511078            0       358875     13252765        12187  ticks
# └ #8  1992 MHz     537640            0       303500     13281578         5343  ticks
# 5.0%┣██▏                                        ┫ 1/20 [00:00<Inf:Inf, InfGs/it]
# 10.0%┣████▊                                          ┫ 2/20 [00:01<00:10, 2it/s]
# 15.0%┣███████                                        ┫ 3/20 [00:01<00:07, 2it/s]
# 20.0%┣█████████▍                                     ┫ 4/20 [00:01<00:06, 2it/s]
# 25.0%┣███████████▊                                   ┫ 5/20 [00:01<00:05, 3it/s]
# 30.0%┣██████████████                                 ┫ 6/20 [00:02<00:05, 3it/s]
# 35.0%┣████████████████▌                              ┫ 7/20 [00:02<00:04, 3it/s]
# 40.0%┣██████████████████▉                            ┫ 8/20 [00:02<00:04, 3it/s]
# 45.0%┣█████████████████████▏                         ┫ 9/20 [00:03<00:04, 3it/s]
# 50.0%┣███████████████████████                       ┫ 10/20 [00:03<00:03, 3it/s]
# 55.0%┣█████████████████████████▎                    ┫ 11/20 [00:03<00:03, 3it/s]
# 60.0%┣███████████████████████████▋                  ┫ 12/20 [00:04<00:03, 3it/s]
# 65.0%┣██████████████████████████████                ┫ 13/20 [00:04<00:02, 3it/s]
# 70.0%┣████████████████████████████████▏             ┫ 14/20 [00:04<00:02, 3it/s]
# 75.0%┣██████████████████████████████████▌           ┫ 15/20 [00:05<00:02, 3it/s]
# 80.0%┣████████████████████████████████████▉         ┫ 16/20 [00:05<00:01, 3it/s]
# 85.0%┣███████████████████████████████████████       ┫ 17/20 [00:05<00:01, 3it/s]
# 90.0%┣█████████████████████████████████████████▍    ┫ 18/20 [00:05<00:01, 3it/s]
# 95.0%┣███████████████████████████████████████████▊  ┫ 19/20 [00:06<00:00, 3it/s]
# 100.0%┣█████████████████████████████████████████████┫ 20/20 [00:06<00:00, 3it/s]
# ┌ Info: Performance stats (MQD loop only)
# │ time [s]                       6.1383565
# │ subwins/s             26.391429041307717
# │ allocations [GB]                    1.95
# │ allocations [MB/subwin]               12.03
# │ time [m]                             0.1
# │ total n subwindows                  3240
# │ n image pairs                         20
# │ n subwindows in FOV                  162
# │ size(subwindows)                 (9, 18)
# │ M, N                            (64, 64)
# │ rhoI, rhoJ                      (40, 40)
# │ allocations [B]               1948925264
# │ allocations [MB]                 1948.93
# │ gc time [s]                    0.4020832
# │ gc stats            Base.GC_Diff(1948925264, 16280, 1, 129447, 3, 0, 402083200, 12, 2)
# │ number of threads                      1
# │ Running on skylake CPU specs:
# │ Intel(R) Core(TM) i7-8550U CPU @ 1.80GHz:
# │        speed         user         nice          sys         idle          irq
# │ #1  1992 MHz     625890            0       603515     12902656        87000  ticks
# │ #2  1992 MHz     325656            0       305437     13500828         8312  ticks
# │ #3  1992 MHz     908500            0       498968     12724453        12109  ticks
# │ #4  1992 MHz     401953            0       296406     13433562         5968  ticks
# │ #5  1992 MHz     668390            0       444109     13019421        10218  ticks
# │ #6  1992 MHz     351343            0       210671     13569906         5843  ticks
# │ #7  1992 MHz     511890            0       359187     13260828        12187  ticks
# └ #8  1992 MHz     539234            0       304015     13288656         5375  ticks
# 5.0%┣██▏                                        ┫ 1/20 [00:00<Inf:Inf, InfGs/it]
# 10.0%┣████▊                                          ┫ 2/20 [00:00<00:09, 2it/s]
# 15.0%┣███████                                        ┫ 3/20 [00:01<00:06, 3it/s]
# 20.0%┣█████████▍                                     ┫ 4/20 [00:01<00:06, 3it/s]
# 25.0%┣███████████▊                                   ┫ 5/20 [00:01<00:05, 3it/s]
# 30.0%┣██████████████                                 ┫ 6/20 [00:02<00:05, 3it/s]
# 35.0%┣████████████████▌                              ┫ 7/20 [00:02<00:04, 3it/s]
# 40.0%┣██████████████████▉                            ┫ 8/20 [00:02<00:04, 3it/s]
# 45.0%┣█████████████████████▏                         ┫ 9/20 [00:02<00:03, 3it/s]
# 50.0%┣███████████████████████                       ┫ 10/20 [00:03<00:03, 3it/s]
# 55.0%┣█████████████████████████▎                    ┫ 11/20 [00:03<00:03, 3it/s]
# 60.0%┣███████████████████████████▋                  ┫ 12/20 [00:03<00:02, 3it/s]
# 65.0%┣██████████████████████████████                ┫ 13/20 [00:04<00:02, 3it/s]
# 70.0%┣████████████████████████████████▏             ┫ 14/20 [00:04<00:02, 3it/s]
# 75.0%┣██████████████████████████████████▌           ┫ 15/20 [00:04<00:02, 3it/s]
# 80.0%┣████████████████████████████████████▉         ┫ 16/20 [00:05<00:01, 3it/s]
# 85.0%┣███████████████████████████████████████       ┫ 17/20 [00:05<00:01, 3it/s]
# 90.0%┣█████████████████████████████████████████▍    ┫ 18/20 [00:05<00:01, 3it/s]
# 95.0%┣███████████████████████████████████████████▊  ┫ 19/20 [00:06<00:00, 3it/s]
# 100.0%┣█████████████████████████████████████████████┫ 20/20 [00:06<00:00, 3it/s]
# ┌ Info: Performance stats (MQD loop only)
# │ time [s]                       6.5803352
# │ subwins/s              24.61880665288905
# │ allocations [GB]                    1.95
# │ allocations [MB/subwin]               12.03
# │ time [m]                            0.11
# │ total n subwindows                  3240
# │ n image pairs                         20
# │ n subwindows in FOV                  162
# │ size(subwindows)                 (9, 18)
# │ M, N                            (64, 64)
# │ rhoI, rhoJ                      (40, 40)
# │ allocations [B]               1948914448
# │ allocations [MB]                 1948.91
# │ gc time [s]                    0.1055063
# │ gc stats            Base.GC_Diff(1948914448, 16280, 1, 129270, 3, 0, 105506300, 11, 0)
# │ number of threads                      1
# │ Running on skylake CPU specs:
# │ Intel(R) Core(TM) i7-8550U CPU @ 1.80GHz:
# │        speed         user         nice          sys         idle          irq
# │ #1  1992 MHz     629656            0       604906     12906828        87187  ticks
# │ #2  1992 MHz     326343            0       305859     13509046         8312  ticks
# │ #3  1992 MHz     913500            0       499515     12728234        12109  ticks
# │ #4  1992 MHz     402656            0       296796     13441796         5984  ticks
# │ #5  1992 MHz     671500            0       444781     13024968        10250  ticks
# │ #6  1992 MHz     351953            0       210890     13578406         5875  ticks
# │ #7  1992 MHz     513328            0       359531     13268375        12187  ticks
# └ #8  1992 MHz     541312            0       304484     13295437         5375  ticks
# 5.0%┣██▏                                        ┫ 1/20 [00:00<Inf:Inf, InfGs/it]
# 10.0%┣████▊                                          ┫ 2/20 [00:01<00:09, 2it/s]
# 15.0%┣███████                                        ┫ 3/20 [00:01<00:07, 3it/s]
# 20.0%┣█████████▍                                     ┫ 4/20 [00:01<00:06, 3it/s]
# 25.0%┣███████████▊                                   ┫ 5/20 [00:01<00:05, 3it/s]
# 30.0%┣██████████████                                 ┫ 6/20 [00:02<00:05, 3it/s]
# 35.0%┣████████████████▌                              ┫ 7/20 [00:02<00:05, 3it/s]
# 40.0%┣██████████████████▉                            ┫ 8/20 [00:02<00:04, 3it/s]
# 45.0%┣█████████████████████▏                         ┫ 9/20 [00:03<00:04, 3it/s]
# 50.0%┣███████████████████████                       ┫ 10/20 [00:03<00:04, 3it/s]
# 55.0%┣█████████████████████████▎                    ┫ 11/20 [00:04<00:03, 3it/s]
# 60.0%┣███████████████████████████▋                  ┫ 12/20 [00:04<00:03, 3it/s]
# 65.0%┣██████████████████████████████                ┫ 13/20 [00:04<00:03, 3it/s]
# 70.0%┣████████████████████████████████▏             ┫ 14/20 [00:05<00:02, 3it/s]
# 75.0%┣██████████████████████████████████▌           ┫ 15/20 [00:05<00:02, 3it/s]
# 80.0%┣████████████████████████████████████▉         ┫ 16/20 [00:05<00:01, 3it/s]
# 85.0%┣███████████████████████████████████████       ┫ 17/20 [00:05<00:01, 3it/s]
# 90.0%┣█████████████████████████████████████████▍    ┫ 18/20 [00:06<00:01, 3it/s]
# 95.0%┣███████████████████████████████████████████▊  ┫ 19/20 [00:06<00:00, 3it/s]
# 100.0%┣█████████████████████████████████████████████┫ 20/20 [00:06<00:00, 3it/s]
# ┌ Info: Performance stats (MQD loop only)
# │ time [s]                       6.7763819
# │ subwins/s             23.906562881292157
# │ allocations [GB]                    1.95
# │ allocations [MB/subwin]               12.03
# │ time [m]                            0.11
# │ total n subwindows                  3240
# │ n image pairs                         20
# │ n subwindows in FOV                  162
# │ size(subwindows)                 (9, 18)
# │ M, N                            (64, 64)
# │ rhoI, rhoJ                      (40, 40)
# │ allocations [B]               1948923648
# │ allocations [MB]                 1948.92
# │ gc time [s]                    0.4337888
# │ gc stats            Base.GC_Diff(1948923648, 16280, 1, 129407, 3, 0, 433788800, 12, 2)
# │ number of threads                      1
# │ Running on skylake CPU specs:
# │ Intel(R) Core(TM) i7-8550U CPU @ 1.80GHz:
# │        speed         user         nice          sys         idle          irq
# │ #1  1992 MHz     631609            0       606281     12913156        87390  ticks
# │ #2  1992 MHz     327125            0       306265     13517500         8312  ticks
# │ #3  1992 MHz     915937            0       500125     12734828        12125  ticks
# │ #4  1992 MHz     403328            0       297046     13450515         6000  ticks
# │ #5  1992 MHz     676703            0       445234     13028953        10265  ticks
# │ #6  1992 MHz     353218            0       211093     13586578         5890  ticks
# │ #7  1992 MHz     515343            0       359859     13275671        12218  ticks
# └ #8  1992 MHz     543328            0       304828     13302734         5375  ticks
# 5.0%┣██▏                                        ┫ 1/20 [00:00<Inf:Inf, InfGs/it]
# 10.0%┣████▊                                          ┫ 2/20 [00:00<00:09, 2it/s]
# 15.0%┣███████                                        ┫ 3/20 [00:01<00:06, 3it/s]
# 20.0%┣█████████▍                                     ┫ 4/20 [00:01<00:06, 3it/s]
# 25.0%┣███████████▊                                   ┫ 5/20 [00:01<00:05, 3it/s]
# 30.0%┣██████████████                                 ┫ 6/20 [00:02<00:05, 3it/s]
# 35.0%┣████████████████▌                              ┫ 7/20 [00:02<00:04, 3it/s]
# 40.0%┣██████████████████▉                            ┫ 8/20 [00:02<00:04, 3it/s]
# 45.0%┣█████████████████████▏                         ┫ 9/20 [00:03<00:04, 3it/s]
# 50.0%┣███████████████████████                       ┫ 10/20 [00:03<00:03, 3it/s]
# 55.0%┣█████████████████████████▎                    ┫ 11/20 [00:03<00:03, 3it/s]
# 60.0%┣███████████████████████████▋                  ┫ 12/20 [00:03<00:03, 3it/s]
# 65.0%┣██████████████████████████████                ┫ 13/20 [00:04<00:02, 3it/s]
# 70.0%┣████████████████████████████████▏             ┫ 14/20 [00:04<00:02, 3it/s]
# 75.0%┣██████████████████████████████████▌           ┫ 15/20 [00:04<00:02, 3it/s]
# 80.0%┣████████████████████████████████████▉         ┫ 16/20 [00:05<00:01, 3it/s]
# 85.0%┣███████████████████████████████████████       ┫ 17/20 [00:05<00:01, 3it/s]
# 90.0%┣█████████████████████████████████████████▍    ┫ 18/20 [00:05<00:01, 3it/s]
# 95.0%┣███████████████████████████████████████████▊  ┫ 19/20 [00:05<00:00, 3it/s]
# 100.0%┣█████████████████████████████████████████████┫ 20/20 [00:06<00:00, 3it/s]
# ┌ Info: Performance stats (MQD loop only)
# │ time [s]                       5.9597749
# │ subwins/s             27.182234684736162
# │ allocations [GB]                    1.95
# │ allocations [MB/subwin]               12.03
# │ time [m]                             0.1
# │ total n subwindows                  3240
# │ n image pairs                         20
# │ n subwindows in FOV                  162
# │ size(subwindows)                 (9, 18)
# │ M, N                            (64, 64)
# │ rhoI, rhoJ                      (40, 40)
# │ allocations [B]               1948918784
# │ allocations [MB]                 1948.92
# │ gc time [s]                     0.088289
# │ gc stats            Base.GC_Diff(1948918784, 16280, 1, 129342, 5, 0, 88289000, 11, 0)
# │ number of threads                      1
# │ Running on skylake CPU specs:
# │ Intel(R) Core(TM) i7-8550U CPU @ 1.80GHz:
# │        speed         user         nice          sys         idle          irq
# ...
# 10.0%┣████▊                                          ┫ 2/20 [00:00<00:08, 2it/s]
# 15.0%┣███████                                        ┫ 3/20 [00:01<00:06, 3it/s]
# 20.0%┣█████████▍                                     ┫ 4/20 [00:01<00:05, 3it/s]
# 25.0%┣███████████▊                                   ┫ 5/20 [00:01<00:05, 3it/s]
# 30.0%┣██████████████                                 ┫ 6/20 [00:01<00:04, 3it/s]
# 35.0%┣████████████████▌                              ┫ 7/20 [00:02<00:04, 3it/s]
# 40.0%┣██████████████████▉                            ┫ 8/20 [00:02<00:04, 3it/s]
# 45.0%┣█████████████████████▏                         ┫ 9/20 [00:02<00:03, 3it/s]
# 50.0%┣███████████████████████                       ┫ 10/20 [00:03<00:03, 3it/s]
# 55.0%┣█████████████████████████▎                    ┫ 11/20 [00:03<00:03, 3it/s]
# 60.0%┣███████████████████████████▋                  ┫ 12/20 [00:04<00:03, 3it/s]
# 65.0%┣██████████████████████████████                ┫ 13/20 [00:04<00:02, 3it/s]
# 70.0%┣████████████████████████████████▏             ┫ 14/20 [00:04<00:02, 3it/s]
# 75.0%┣██████████████████████████████████▌           ┫ 15/20 [00:04<00:02, 3it/s]
# 80.0%┣████████████████████████████████████▉         ┫ 16/20 [00:05<00:01, 3it/s]
# 85.0%┣███████████████████████████████████████       ┫ 17/20 [00:05<00:01, 3it/s]
# 90.0%┣█████████████████████████████████████████▍    ┫ 18/20 [00:05<00:01, 3it/s]
# 95.0%┣███████████████████████████████████████████▊  ┫ 19/20 [00:05<00:00, 3it/s]
# 100.0%┣█████████████████████████████████████████████┫ 20/20 [00:06<00:00, 3it/s]
# ┌ Info: Performance stats (MQD loop only)
# │ time [s]                       5.8176602
# │ subwins/s             27.846246503018516
# │ allocations [GB]                    1.95
# │ allocations [MB/subwin]               12.03
# │ time [m]                             0.1
# │ total n subwindows                  3240
# │ n image pairs                         20
# │ n subwindows in FOV                  162
# │ size(subwindows)                 (9, 18)
# │ M, N                            (64, 64)
# │ rhoI, rhoJ                      (40, 40)
# │ allocations [B]               1948927168
# │ allocations [MB]                 1948.93
# │ gc time [s]                    0.4073735
# │ gc stats            Base.GC_Diff(1948927168, 16280, 1, 129359, 5, 0, 407373500, 12, 2)
# │ number of threads                      1
# │ Running on skylake CPU specs:
# │ Intel(R) Core(TM) i7-8550U CPU @ 1.80GHz:
# │        speed         user         nice          sys         idle          irq
# │ #1  1992 MHz     634609            0       607765     12926265        87515  ticks
# │ #2  1992 MHz     327781            0       306796     13533921         8328  ticks
# │ #3  1992 MHz     919109            0       501187     12748203        12156  ticks
# │ #4  1992 MHz     404234            0       297406     13466859         6000  ticks
# │ #5  1992 MHz     678187            0       446031     13044281        10281  ticks
# │ #6  1992 MHz     354531            0       211531     13602437         5906  ticks
# │ #7  1992 MHz     516796            0       360562     13291125        12281  ticks
# └ #8  1992 MHz     547125            0       305828     13315531         5375  ticks
# 5.0%┣██▏                                        ┫ 1/20 [00:00<Inf:Inf, InfGs/it]
# 10.0%┣████▊                                          ┫ 2/20 [00:00<00:08, 2it/s]
# 15.0%┣███████                                        ┫ 3/20 [00:01<00:06, 3it/s]
# 20.0%┣█████████▍                                     ┫ 4/20 [00:01<00:05, 3it/s]
# 25.0%┣███████████▊                                   ┫ 5/20 [00:01<00:05, 3it/s]
# 30.0%┣██████████████                                 ┫ 6/20 [00:01<00:04, 3it/s]
# 35.0%┣████████████████▌                              ┫ 7/20 [00:02<00:04, 4it/s]
# 40.0%┣██████████████████▉                            ┫ 8/20 [00:02<00:03, 4it/s]
# 45.0%┣█████████████████████▏                         ┫ 9/20 [00:02<00:03, 4it/s]
# 50.0%┣███████████████████████                       ┫ 10/20 [00:03<00:03, 4it/s]
# 55.0%┣█████████████████████████▎                    ┫ 11/20 [00:03<00:03, 4it/s]
# 60.0%┣███████████████████████████▋                  ┫ 12/20 [00:03<00:02, 4it/s]
# 65.0%┣██████████████████████████████                ┫ 13/20 [00:03<00:02, 4it/s]
# 70.0%┣████████████████████████████████▏             ┫ 14/20 [00:04<00:02, 4it/s]
# 75.0%┣██████████████████████████████████▌           ┫ 15/20 [00:04<00:01, 4it/s]
# 80.0%┣████████████████████████████████████▉         ┫ 16/20 [00:04<00:01, 3it/s]
# 85.0%┣███████████████████████████████████████       ┫ 17/20 [00:05<00:01, 3it/s]
# 90.0%┣█████████████████████████████████████████▍    ┫ 18/20 [00:05<00:01, 3it/s]
# 95.0%┣███████████████████████████████████████████▊  ┫ 19/20 [00:05<00:00, 3it/s]
# 100.0%┣█████████████████████████████████████████████┫ 20/20 [00:05<00:00, 3it/s]
# ┌ Info: Performance stats (MQD loop only)
# │ time [s]                       5.6942922
# │ subwins/s             28.449541103633567
# │ allocations [GB]                    1.95
# │ allocations [MB/subwin]               12.03
# │ time [m]                            0.09
# │ total n subwindows                  3240
# │ n image pairs                         20
# │ n subwindows in FOV                  162
# │ size(subwindows)                 (9, 18)
# │ M, N                            (64, 64)
# │ rhoI, rhoJ                      (40, 40)
# │ allocations [B]               1948921616
# │ allocations [MB]                 1948.92
# │ gc time [s]                    0.0868793
# │ gc stats            Base.GC_Diff(1948921616, 16280, 1, 129389, 3, 0, 86879300, 11, 0)
# │ number of threads                      1
# │ Running on skylake CPU specs:
# │ Intel(R) Core(TM) i7-8550U CPU @ 1.80GHz:
# │        speed         user         nice          sys         idle          irq
# │ #1  1992 MHz     636187            0       608437     12932578        87640  ticks
# │ #2  1992 MHz     328265            0       306937     13541859         8328  ticks
# │ #3  1992 MHz     920734            0       501671     12754656        12156  ticks
# │ #4  1992 MHz     404687            0       297500     13474875         6000  ticks
# │ #5  1992 MHz     678750            0       446406     13051906        10296  ticks
# │ #6  1992 MHz     354937            0       211546     13610562         5906  ticks
# │ #7  1992 MHz     517062            0       360640     13299328        12281  ticks
# └ #8  1992 MHz     548796            0       306015     13322234         5390  ticks
# 5.0%┣██▏                                        ┫ 1/20 [00:00<Inf:Inf, InfGs/it]
# 10.0%┣████▊                                          ┫ 2/20 [00:00<00:09, 2it/s]
# 15.0%┣███████                                        ┫ 3/20 [00:01<00:06, 3it/s]
# 20.0%┣█████████▍                                     ┫ 4/20 [00:01<00:05, 3it/s]
# 25.0%┣███████████▊                                   ┫ 5/20 [00:01<00:05, 3it/s]
# 30.0%┣██████████████                                 ┫ 6/20 [00:02<00:04, 3it/s]
# 35.0%┣████████████████▌                              ┫ 7/20 [00:02<00:04, 3it/s]
# 40.0%┣██████████████████▉                            ┫ 8/20 [00:02<00:04, 3it/s]
# 45.0%┣█████████████████████▏                         ┫ 9/20 [00:02<00:03, 3it/s]
# 50.0%┣███████████████████████                       ┫ 10/20 [00:03<00:03, 3it/s]
# 55.0%┣█████████████████████████▎                    ┫ 11/20 [00:03<00:03, 3it/s]
# 60.0%┣███████████████████████████▋                  ┫ 12/20 [00:04<00:03, 3it/s]
# 65.0%┣██████████████████████████████                ┫ 13/20 [00:04<00:02, 3it/s]
# 70.0%┣████████████████████████████████▏             ┫ 14/20 [00:04<00:02, 3it/s]
# 75.0%┣██████████████████████████████████▌           ┫ 15/20 [00:04<00:02, 3it/s]
# 80.0%┣████████████████████████████████████▉         ┫ 16/20 [00:05<00:01, 3it/s]
# 85.0%┣███████████████████████████████████████       ┫ 17/20 [00:05<00:01, 3it/s]
# 90.0%┣█████████████████████████████████████████▍    ┫ 18/20 [00:05<00:01, 3it/s]
# 95.0%┣███████████████████████████████████████████▊  ┫ 19/20 [00:06<00:00, 3it/s]
# 100.0%┣█████████████████████████████████████████████┫ 20/20 [00:06<00:00, 3it/s]
# ┌ Info: Performance stats (MQD loop only)
# │ time [s]                       6.2070565
# │ subwins/s              26.09932743483163
# │ allocations [GB]                    1.95
# │ allocations [MB/subwin]               12.03
# │ time [m]                             0.1
# │ total n subwindows                  3240
# │ n image pairs                         20
# │ n subwindows in FOV                  162
# │ size(subwindows)                 (9, 18)
# │ M, N                            (64, 64)
# │ rhoI, rhoJ                      (40, 40)
# │ allocations [B]               1948919280
# │ allocations [MB]                 1948.92
# │ gc time [s]                    0.4126947
# │ gc stats            Base.GC_Diff(1948919280, 16280, 1, 129379, 5, 0, 412694700, 12, 2)
# │ number of threads                      1
# │ Running on skylake CPU specs:
# │ Intel(R) Core(TM) i7-8550U CPU @ 1.80GHz:
# │        speed         user         nice          sys         idle          irq
# │ #1  1992 MHz     638078            0       608953     12939343        87750  ticks
# │ #2  1992 MHz     328578            0       307046     13550609         8328  ticks
# │ #3  1992 MHz     922796            0       502046     12761390        12156  ticks
# │ #4  1992 MHz     404921            0       297734     13483578         6000  ticks
# │ #5  1992 MHz     679703            0       446812     13059718        10312  ticks
# │ #6  1992 MHz     355406            0       211562     13619265         5906  ticks
# │ #7  1992 MHz     517625            0       360906     13307687        12312  ticks
# └ #8  1992 MHz     550625            0       306375     13329218         5390  ticks
# 5.3%┣██▎                                        ┫ 1/19 [00:00<Inf:Inf, InfGs/it]
# 10.5%┣█████                                          ┫ 2/19 [00:00<00:08, 2it/s]
# 15.8%┣███████▍                                       ┫ 3/19 [00:01<00:06, 3it/s]
# 21.1%┣██████████                                     ┫ 4/19 [00:01<00:05, 3it/s]
# 26.3%┣████████████▍                                  ┫ 5/19 [00:01<00:05, 3it/s]
# 31.6%┣██████████████▉                                ┫ 6/19 [00:02<00:05, 3it/s]
# 36.8%┣█████████████████▎                             ┫ 7/19 [00:02<00:04, 3it/s]
# 42.1%┣███████████████████▉                           ┫ 8/19 [00:02<00:04, 3it/s]
# 47.4%┣██████████████████████▎                        ┫ 9/19 [00:03<00:03, 3it/s]
# 52.6%┣████████████████████████▏                     ┫ 10/19 [00:03<00:03, 3it/s]
# 57.9%┣██████████████████████████▋                   ┫ 11/19 [00:03<00:03, 3it/s]
# 63.2%┣█████████████████████████████                 ┫ 12/19 [00:04<00:02, 3it/s]
# 68.4%┣███████████████████████████████▌              ┫ 13/19 [00:04<00:02, 3it/s]
# 73.7%┣██████████████████████████████████            ┫ 14/19 [00:04<00:02, 3it/s]
# 78.9%┣████████████████████████████████████▎         ┫ 15/19 [00:04<00:01, 3it/s]
# 84.2%┣██████████████████████████████████████▊       ┫ 16/19 [00:05<00:01, 3it/s]
# 89.5%┣█████████████████████████████████████████▏    ┫ 17/19 [00:05<00:01, 3it/s]
# 94.7%┣███████████████████████████████████████████▋  ┫ 18/19 [00:05<00:00, 3it/s]
# 100.0%┣█████████████████████████████████████████████┫ 19/19 [00:06<00:00, 3it/s]
# ┌ Info: Performance stats (MQD loop only)
# │ time [s]                       5.8409312
# │ subwins/s             27.735303576251678
# │ allocations [GB]                    1.85
# │ allocations [MB/subwin]               11.43
# │ time [m]                             0.1
# │ total n subwindows                  3078
# │ n image pairs                         19
# │ n subwindows in FOV                  162
# │ size(subwindows)                 (9, 18)
# │ M, N                            (64, 64)
# │ rhoI, rhoJ                      (40, 40)
# │ allocations [B]               1851478128
# │ allocations [MB]                 1851.48
# │ gc time [s]                    0.1009306
# │ gc stats            Base.GC_Diff(1851478128, 15466, 1, 123022, 3, 0, 100930600, 9, 0)
# │ number of threads                      1
# │ Running on skylake CPU specs:
# │ Intel(R) Core(TM) i7-8550U CPU @ 1.80GHz:
# │        speed         user         nice          sys         idle          irq
# │ #1  1992 MHz     640062            0       609796     12945640        87875  ticks
# │ #2  1992 MHz     329421            0       307437     13558500         8328  ticks
# │ #3  1992 MHz     924718            0       502796     12767843        12171  ticks
# │ #4  1992 MHz     405281            0       297890     13492187         6000  ticks
# │ #5  1992 MHz     680953            0       447171     13067234        10312  ticks
# │ #6  1992 MHz     356046            0       211625     13627687         5906  ticks
# │ #7  1992 MHz     518593            0       361281     13315468        12328  ticks
# └ #8  1992 MHz     552609            0       306843     13335890         5421  ticks
# 5.3%┣██▎                                        ┫ 1/19 [00:00<Inf:Inf, InfGs/it]
# 10.5%┣█████                                          ┫ 2/19 [00:00<00:08, 2it/s]
# 15.8%┣███████▍                                       ┫ 3/19 [00:01<00:06, 3it/s]
# 21.1%┣██████████                                     ┫ 4/19 [00:01<00:05, 3it/s]
# 26.3%┣████████████▍                                  ┫ 5/19 [00:01<00:05, 3it/s]
# 31.6%┣██████████████▉                                ┫ 6/19 [00:02<00:04, 3it/s]
# 36.8%┣█████████████████▎                             ┫ 7/19 [00:02<00:04, 3it/s]
# 42.1%┣███████████████████▉                           ┫ 8/19 [00:02<00:04, 3it/s]
# 47.4%┣██████████████████████▎                        ┫ 9/19 [00:03<00:04, 3it/s]
# 52.6%┣████████████████████████▏                     ┫ 10/19 [00:03<00:03, 3it/s]
# 57.9%┣██████████████████████████▋                   ┫ 11/19 [00:04<00:03, 3it/s]
# 63.2%┣█████████████████████████████                 ┫ 12/19 [00:04<00:02, 3it/s]
# 68.4%┣███████████████████████████████▌              ┫ 13/19 [00:04<00:02, 3it/s]
# 73.7%┣██████████████████████████████████            ┫ 14/19 [00:04<00:02, 3it/s]
# 78.9%┣████████████████████████████████████▎         ┫ 15/19 [00:05<00:01, 3it/s]
# 84.2%┣██████████████████████████████████████▊       ┫ 16/19 [00:05<00:01, 3it/s]
# 89.5%┣█████████████████████████████████████████▏    ┫ 17/19 [00:05<00:01, 3it/s]
# 94.7%┣███████████████████████████████████████████▋  ┫ 18/19 [00:06<00:00, 3it/s]
# 100.0%┣█████████████████████████████████████████████┫ 19/19 [00:06<00:00, 3it/s]
# ┌ Info: Performance stats (MQD loop only)
# │ time [s]                       6.1087109
# │ subwins/s              26.51950675878277
# │ allocations [GB]                    1.85
# │ allocations [MB/subwin]               11.43
# │ time [m]                             0.1
# │ total n subwindows                  3078
# │ n image pairs                         19
# │ n subwindows in FOV                  162
# │ size(subwindows)                 (9, 18)
# │ M, N                            (64, 64)
# │ rhoI, rhoJ                      (40, 40)
# │ allocations [B]               1851482160
# │ allocations [MB]                 1851.48
# │ gc time [s]                    0.4693441
# │ gc stats            Base.GC_Diff(1851482160, 15466, 1, 122968, 5, 0, 469344100, 12, 2)
# │ number of threads                      1
# │ Running on skylake CPU specs:
# │ Intel(R) Core(TM) i7-8550U CPU @ 1.80GHz:
# │        speed         user         nice          sys         idle          irq
# │ #1  1992 MHz     642031            0       610390     12952015        87984  ticks
# │ #2  1992 MHz     330078            0       307609     13566609         8328  ticks
# │ #3  1992 MHz     926421            0       503671     12774203        12187  ticks
# │ #4  1992 MHz     405734            0       298031     13500531         6000  ticks
# │ #5  1992 MHz     681656            0       447750     13074890        10312  ticks
# │ #6  1992 MHz     356296            0       211703     13636281         5906  ticks
# │ #7  1992 MHz     519390            0       361500     13323390        12359  ticks
# └ #8  1992 MHz     554937            0       307046     13342281         5437  ticks

# %%
meanmagsds = -meanmagsds
irqivTus = Array(Dates.Time(Dates.Hour(3), Dates.Minute(25)):Dates.Second(395):Dates.Time(Dates.Hour(7), Dates.Minute(23)))
irqivTus_str = string.(irqivTus)
irqivTds = Array(Dates.Time(Dates.Hour(20), Dates.Minute(58)):Dates.Second(400):Dates.Time(Dates.Hour(23), Dates.Minute(11)))
irqivTds_str = string.(irqivTds)

irqivDTus = Dates.DateTime[]
irqivDTds = Dates.DateTime[]
for i = 1:length(irqivTus)
    push!(irqivDTus, Dates.Date("07/14/2022", "m/d/y") + irqivTus[i]) # Times in EDT
end
for i = 1:length(irqivTds)
    push!(irqivDTds, Dates.Date("07/14/2022", "m/d/y") + irqivTds[i]) # Times in EDT
end

plt.close("all")
fig, (ax1, ax2) = plt.subplots(2)
ax1.plot(irqivTus_str, meanmagsus, linewidth = 2, color = "red")
ax2.plot(irqivTds_str, meanmagsds, linewidth = 2, color = "red")
ax1.set_xticks(1:6:length(meanmagsus), #rotation = 45
 )
ax2.set_xticks(1:4:length(meanmagsds), #rotation = 45
 )
plt.xlabel("Time - July 14, 2022")
plt.rc("font",size=24)
fig.text(0.04, 0.5, "IR-QIV mean vector magnitude (pix)", va="center", rotation="vertical")
ax1.legend(["Upstream outgoing tide"])
ax2.legend(["Downstream incoming tide"])
# Out:
# PyObject <matplotlib.legend.Legend object at 0x00000000AB112670>

# %%
# ax.invert_yaxis()
# angles = "xy"
# Statistics.mean(subpix_shifts_j[:,:,:], dim)

plt.close("all")
fig,ax = plt.subplots()
im = ax.imshow(I1images[:,:,1], alpha=0.3, vmin=8700, vmax=11800)
q = ax.quiver(j,i, jmean, imean, angles="xy")
# ax.plot(q)
# ax.invert_yaxis()
# Out:
# PyObject <matplotlib.quiver.Quiver object at 0x00000000912DE550>

# %%
extrema(I1images[1]).|>Int
# Out:
# (8642, 11852)

# %%
# For methane experiment
using Statistics
mean(I1images.Frames, dims=3)
# set indices to inf
# Out:
# 784×1344×1 Array{Float64, 3}:
# [:, :, 1] =
#  9836.7  9845.8  9842.4  9839.0  …  10458.6  10453.1  10442.8  10455.5
#  9851.5  9844.1  9846.6  9855.3     10460.3  10437.1  10456.7  10456.4
#  9848.2  9846.6  9844.9  9848.8     10451.1  10452.4  10447.2  10459.5
#  9850.7  9845.3  9844.4  9842.9     10453.6  10449.4  10456.8  10441.5
#  9828.0  9828.3  9844.7  9840.2     10458.2  10442.0  10456.7  10451.5
#  9802.4  9838.3  9837.3  9847.0  …  10449.2  10454.2  10454.2  10449.9
#  9778.6  9805.4  9837.0  9841.5     10460.2  10461.6  10452.3  10463.2
#  9757.9  9776.1  9822.5  9845.6     10458.2  10451.0  10460.3  10464.8
#  9745.7  9782.9  9806.2  9836.0     10456.4  10464.2  10459.2  10460.6
#  9740.0  9783.2  9817.2  9839.3     10450.0  10454.9  10454.4  10459.7
#  9769.1  9801.4  9836.0  9844.9  …  10456.7  10456.5  10460.6  10454.5
#  9800.8  9832.5  9858.5  9855.1     10453.5  10452.5  10455.0  10458.6
#  9831.2  9861.3  9862.6  9869.5     10463.6  10460.7  10457.9  10448.3
#     ⋮                            ⋱      ⋮
#  9820.7  9818.3  9829.2  9830.2     10366.0  10368.1  10361.9  10370.0
#  9818.8  9825.4  9811.6  9816.8     10357.7  10369.1  10366.4  10372.3
#  9802.3  9817.3  9827.6  9807.4     10371.7  10364.9  10367.3  10374.4
#  9803.0  9803.5  9827.5  9806.1  …  10373.8  10360.4  10361.6  10359.7
#  9783.1  9802.0  9802.8  9802.3     10352.1  10348.6  10362.9  10361.1
#  9782.2  9795.6  9792.2  9792.0     10361.6  10350.3  10347.4  10368.2
#  9789.0  9777.5  9777.0  9776.0     10355.6  10349.8  10351.8  10352.8
#  9753.8  9783.2  9786.7  9760.9     10358.0  10351.9  10350.7  10350.4
#  9758.5  9759.4  9755.9  9762.8  …  10360.2  10358.4  10363.1  10359.6
#  9753.3  9765.9  9764.4  9788.1     10368.5  10358.6  10365.2  10363.4
#  9756.2  9751.7  9758.2  9773.1     10367.8  10366.1  10364.0  10364.3
#  9765.2  9759.5  9768.4  9778.9     10366.1  10372.7  10364.6  10371.3

# %%
kb_model = CSV.read(raw"C:\Users\evanh\Box\Cornell\CACO\2022\Analysis\Modeling\hr_heb_Verified_(m)_38834_dt360s_230418.csv", DataFrames.DataFrame)
mh_model = CSV.read(raw"C:\Users\evanh\Box\Cornell\CACO\2022\Analysis\Modeling\Delft3D_HR_Discharge.csv", DataFrames.DataFrame)
GMT_to_EDT = Dates.Hour(4)
kb_model.date_time = Dates.DateTime.(kb_model.date_time, "yyyy-mm-dd HH:MM:SS") - GMT_to_EDT # Convert to EDT here!
mh_model.Datetime = Dates.DateTime.(mh_model.Datetime, "m/d/y H:M") - GMT_to_EDT # Convert to ED
kb_model.time = Dates.Time.(kb_model.date_time)
mh_model.time = Dates.Time.(mh_model.Datetime)
# kb_time = Dates.Time[]
start = Dates.DateTime("07/14/2022 00:00:00", "m/d/y H:M:S")
stop = start + Dates.Day(1)
kb_filt = kb_model[(kb_model.date_time.>= start) .& (kb_model.date_time.<= stop), :]
mh_filt = mh_model[(mh_model.Datetime.>= start) .& (mh_model.Datetime.<= stop), :]
# timetix = 



# Plot results
plt.close("all")
fig, ax = plt.subplots()
ax.plot(kb_filt.date_time, kb_filt.Qtotal_m3s, linewidth = 2)
ax.plot(mh_filt.Datetime, mh_filt."Total_Discharge_m3/s", linewidth = 2)
ax.plot(irqivDTus, meanmagsus, linewidth = 2)
ax.plot(irqivDTds, meanmagsds, linewidth = 2)
plt.rc("font",size=24)
plt.ylabel(LaTeXStrings.LaTeXString("Modeled volumetric flux (m^3/s) \n IR-QIV mean vector magnitude (pix)"))
plt.xlabel("Hour of day (July 14, 2022)")
plt.legend(["Model: hydraulic mass balance", "Model: depth-averaged Delft3D", "IR-QIV: upstream outgoing tide", "IR-QIV: downstream incoming tide"], loc = "upper center")
plt.ylim([-20, 60])
# Out:
# (-20.0, 60.0)

# %%
mh_filt.time[end]
# Out:
# 00:00:00

# %%
string(replace("test string", r"(test string)" => SubstitutionString("\\1\nline 2")))
# Out:
# "test string\nline 2"

# %%
mh_filt.time
# Array(irqivTus)
# mh_filt.Datetime
# Dates.Time(kb_filt.date_time)

test = Dates.Date("07/14/2022", "m/d/y") + mh_model.time(:)
test
mh_filt.Datetime[1]
# Dates.Time(string(mh_model.time[1]),"H:M:S")
# mh_model.time[1]
# Out:
# MethodError: objects of type Vector{Dates.Time} are not callable
# Use square brackets [] for indexing an Array.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[99]:6

# %%
# Write tiffs from .ats file
Pkg.activate(expanduser("~/.julia/dev/IRQIV/")) # path to IRQIV directory
using IRQIV

imageN = 800

FLIRfile_inc_us = raw"D:\CNRD_IR\Rec-DeFreesLab_-003334.ats" # First file after switching to 20hz
# FLIRfile_out = raw"D:\CNRD_IR\Rec-DeFreesLab_-003367.ats"
# FLIRfile_inc_ds = raw"D:\CNRD_IR\Rec-DeFreesLab_-003497.ats"
ats_year = 2022
# @assert isfile(FLIRfile_inc_us)
# @assert isfile(FLIRfile_inc_ds)

USimage = LoadATSImageSequence(raw"E:\CACO\2022\CNRD_IR\Rec-DeFreesLab_-003334.ats", 1200, ats_year)
save_path = raw"C:\Users\evanh\Box\Cornell\CACO\2022\IR_TIFF"
filenum = "003334"
framerate = "20"
HDF5_path = joinpath(save_path, "CNRD_" * filenum * "_" * framerate * "hz.h5")
Frames = USimage.Frames
HDF5.h5open(HDF5_path,  "w") do file # do file automatically closes .h5 file when done
    write(file, "Frames", Frames)
end

# Check outputs:
# c = HDF5.h5open(HDF5_path, "r") do file1
#     read(file1, "Frames")
# end
# c

# start = 1
# k = 1
# for i = 1:4
#     ATSseg = range(start, step=1, length=imageN)
#     USimages = LoadATSImageSequence(FLIRfile_inc_us, ATSseg, ats_year)
# #     DSimages = LoadATSImageSequence(FLIRfile_inc_ds, ATSseg, ats_year)
#     for j = 1:imageN
#         filename_inc_us = joinpath(raw"E:\CACO\2022\IR_TIFF\CNRD_US_20hz", "inc_us_" * lpad(k, 4, "0") * ".tif")
# #         filename_inc_ds = joinpath(raw"D:\IR_TIFF\CNRD_DS", "inc_ds_" * lpad(k, 4, "0") * ".tif")
#         img_inc_us = reinterpret(TiffImages.Gray{FixedPointNumbers.N0f16}, USimages[j])
# #         img_inc_ds = reinterpret(TiffImages.Gray{FixedPointNumbers.N0f16}, DSimages[j])
#         TiffImages.save(filename_inc_us, img_inc_us)
# #         TiffImages.save(filename_inc_ds, img_inc_ds)
#         k = k+1
#     end
#     start = start + imageN
# end
# Out:
#   Activating new environment at `C:\Users\evanh\Box\Cornell\CACO\2022\Analysis\IRQIV.jl\CACO_2022_jl\~\.julia\dev\IRQIV\Project.toml`
# 784×1344×1200 Array{UInt16, 3}:
# [:, :, 1] =
#  0x29f6  0x29f5  0x29e9  0x29db  0x29e4  …  0x2da9  0x2daf  0x2db1  0x2dc5
#  0x2a08  0x29fa  0x29f1  0x29e7  0x29ed     0x2d9e  0x2dae  0x2dbf  0x2dcf
#  0x2a03  0x29fb  0x2a06  0x29f5  0x29ee     0x2da8  0x2db1  0x2dce  0x2dd5
#  0x2a17  0x2a0f  0x2a03  0x29fb  0x29ea     0x2daf  0x2db6  0x2dbe  0x2dc1
#  0x2a04  0x29fb  0x2a07  0x2a00  0x2a03     0x2db9  0x2db9  0x2dcf  0x2dd8
#  0x2a0a  0x2a1f  0x2a0b  0x2a03  0x2a01  …  0x2dbb  0x2dd2  0x2dbf  0x2dbe
#  0x2a19  0x2a05  0x2a11  0x29fe  0x2a14     0x2dcf  0x2dd0  0x2dc5  0x2db2
#  0x2a18  0x2a1c  0x2a0f  0x2a0b  0x2a19     0x2dcd  0x2db6  0x2dba  0x2dc2
#  0x2a19  0x2a1f  0x2a15  0x2a19  0x2a0a     0x2dc7  0x2db1  0x2dae  0x2dac
#  0x2a16  0x2a1d  0x2a16  0x2a19  0x2a14     0x2dc1  0x2db3  0x2da9  0x2d9c
#  0x2a22  0x2a16  0x2a10  0x2a0e  0x2a1b  …  0x2db1  0x2d9f  0x2d9b  0x2d8c
#  0x2a1e  0x2a18  0x2a26  0x2a25  0x2a1e     0x2d96  0x2d8a  0x2d8e  0x2d87
#  0x2a24  0x2a22  0x2a19  0x2a20  0x2a2b     0x2d88  0x2d78  0x2d76  0x2d79
#       ⋮                                  ⋱       ⋮
#  0x2964  0x2962  0x2971  0x2981  0x2980     0x2d90  0x2d8a  0x2d90  0x2d98
